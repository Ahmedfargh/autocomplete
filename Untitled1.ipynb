# %%
import nltk
import pandas as pd
from collections import Counter
from nltk.tokenize import TreebankWordTokenizer
from nltk import ngrams
import random
import numpy as np

# %%
dataset_train=pd.read_csv("total_train.csv")
dataset_train
# Out:
#        Unnamed: 0  Unnamed: 0.1  \
# 0               0             0
# 1               1             1
# 2               2             2
# 3               3             3
# 4               4             4
# ...           ...           ...
# 13779        1954          1954
# 13780        1955          1955
# 13781        1956          1956
# 13782        1957          1957
# 13783        1958          1958
#
#                                             total_string
# 0      Add another song to the Cita Romantica playlist.
# 1       add clem burke in my playlist Pre-Party R&B Jams
# 2                Add Live from Aragon Ballroom to Trapeo
# 3                      add Unite and Win to my night out
# 4                    Add track to my Digster Future Hits
# ...                                                  ...
# 13779  Can a I get the movie schedule for Sympathy fo...
# 13780  Find movie schedules for animated movies aroun...
# 13781              what time is Bordertown Trail showing
# 13782  in the neighbourhood find movies with movie times
# 13783                 What cinema has the closest movies
#
# [13784 rows x 3 columns]

# %%
class Preprocessor:
    def __init__(self):
        self.tokenizer=TreebankWordTokenizer()
    def tokenize(self,text):
        return self.tokenizer.tokenize(text.lower())
    def get_ngram(self,text):
        return list(ngrams(self.tokenizer.tokenize(text.lower()),2))

# %%
processor=Preprocessor()
dataset_train["bigram"]=dataset_train["total_string"].map(processor.get_ngram)

# %%
dataset_train["bigram"][0]
# Out:
# [('add', 'another'),
#  ('another', 'song'),
#  ('song', 'to'),
#  ('to', 'the'),
#  ('the', 'cita'),
#  ('cita', 'romantica'),
#  ('romantica', 'playlist'),
#  ('playlist', '.')]

# %%
class HMM:
    def __init__(self,datatrain):
        self.train_data=datatrain
        self._counter={}
        self.processor=Preprocessor()
    def is_trained(self):
        return len(self.counter)==0
    def train(self):
        for data in self.train_data:
            for bigram in data:
                if bigram[0] in self._counter.keys():
                    if bigram[1] in self._counter[bigram[0]].keys():
                        self._counter[bigram[0]][bigram[1]]+=1
                    else:
                        self._counter[bigram[0]][bigram[1]]=1 
                    continue
                else:
                    self._counter[bigram[0]]={bigram[1]:1}
                    continue
        return True
    def get_counter(self):
        return self._counter
    def predict_next_word(self,sent):
        bigram=self.processor.get_ngram(sent)
        last_one=bigram[len(bigram)-1]
        sencond_words_list=self._counter[last_one[1]]
        if len(sencond_words_list)==0:
            self._counter[last_one[1]]={}
            return {"next_word":" ","prob":1}
        indicator={}
        first_word_counter=0
        best_choise=self._counter[last_one[1]][list(self._counter[last_one[1]].keys())[0]]
        best_word=list(self._counter[last_one[1]].keys())[3]
        for word in list(self._counter[last_one[1]].keys()):
            first_word_counter+=self._counter[last_one[1]][word]
        _words=[]
        _probs=[]
        for word in list(sencond_words_list.keys()):
            if sencond_words_list[word]> sencond_words_list[best_word]:
                best_word=word
                best_choise=sencond_words_list[best_word]
                if not word in _words:                    
                    _words.append(best_word)
                    _probs.append(best_choise/first_word_counter)
        i=0
        while i<4:
            random_word=random.choice(list(sencond_words_list.keys()))
            _words.append(random_word)
            _probs.append(sencond_words_list[random_word]/first_word_counter)
            i+=1
        return {"next_word":best_word,"prob":best_choise/first_word_counter},_words,_probs
    def predict_next_word_given_first_letters(self,sent):
        sent=sent.lower().split(" ")
        last_word_list=self._counter[sent[len(sent)-2]]
        first_char=sent[len(sent)-1]
        candidate={}
        counting=0
        for word in list(last_word_list.keys()):
            if word.startswith(first_char):
                candidate[word]=last_word_list[word]
            counting+=1
        if len(candidate)==0:
            return "undefined_word"
        best_choise=candidate[list(candidate.keys())[0]]
        best_word=list(candidate.keys())[0]
        _words=[]
        _probs=[]
        for word in list(candidate.keys()):
            if best_choise<candidate[word]:
                print(candidate[word])
                best_word=word
                best_choise=candidate[word]
                _words.append(best_word)
                _probs.append(best_choise/counting)
        prob=best_choise/counting
        i=0
        while i<2:
            random_word=random.choice(list(candidate.keys()))
            _words.append(random_word)
            _probs.append(candidate[random_word]/counting)
            i+=1
        return {"next_word":best_word,"prob":prob},_words,_probs

# %%
hmm=HMM(dataset_train["bigram"].values)

# %%
hmm.train()
# Out:
# True

# %%
hmm.get_counter()
# Out:
# {'add': {'another': 25,
#   'clem': 1,
#   'live': 2,
#   'unite': 1,
#   'track': 31,
#   'the': 163,
#   'spanish': 2,
#   'album': 22,
#   'tranquility': 1,
#   'd': 2,
#   'to': 20,
#   'caleigh': 1,
#   'children': 1,
#   '9th': 1,
#   'slimm': 1,
#   'always': 1,
#   'song': 29,
#   'an': 27,
#   'hey': 1,
#   'esquivando': 1,
#   'wiktor': 1,
#   'this': 272,
#   'tune': 40,
#   'monsters': 1,
#   'a': 95,
#   'ross': 1,
#   'some': 8,
#   'paulinho': 1,
#   'eef': 2,
#   'olga': 1,
#   'firehouse': 1,
#   'progress': 1,
#   'quicksand': 1,
#   'feel': 1,
#   'vl': 1,
#   'how': 2,
#   'norma': 1,
#   'kirk': 1,
#   'on': 1,
#   'kjetil': 2,
#   'xanadu': 1,
#   'gina': 1,
#   'ik': 1,
#   'something': 15,
#   'runaljod': 1,
#   'absolutely': 1,
#   'gn': 1,
#   'blood': 2,
#   'written': 1,
#   'cordell': 1,
#   'sonntag': 1,
#   'gareth': 1,
#   '100': 1,
#   'yuna': 2,
#   'nothing': 2,
#   'cj': 1,
#   'ernie': 1,
#   'ajoy': 1,
#   'anthony': 1,
#   'as': 1,
#   'silver': 1,
#   'more': 1,
#   'club': 1,
#   'eric': 3,
#   'gregg': 1,
#   'confessions': 1,
#   'tobymac': 1,
#   'buddy': 2,
#   'vera': 1,
#   'michael': 4,
#   'angela': 1,
#   'artist': 33,
#   'joelia': 1,
#   'alain': 1,
#   'steve': 4,
#   'satisfied': 1,
#   'billy': 3,
#   'ramble': 1,
#   'lady': 1,
#   'famous': 1,
#   'shawn': 1,
#   'bonobo': 1,
#   'hold': 2,
#   'tobias': 1,
#   'jack': 2,
#   'jan': 1,
#   'rupee': 1,
#   'liberty': 1,
#   'gene': 1,
#   'david': 4,
#   'joplin': 1,
#   'harry': 2,
#   'partners': 1,
#   'no': 4,
#   'ali': 1,
#   'sammy': 1,
#   '2120': 1,
#   'turk': 1,
#   'parempi': 1,
#   'exit': 1,
#   'darkest': 1,
#   'global': 1,
#   'bslade': 1,
#   'j': 3,
#   'country': 2,
#   'ian': 3,
#   'paul': 4,
#   'nana': 3,
#   'viktor': 2,
#   'connee': 1,
#   'nicole': 1,
#   'claudine': 1,
#   'kurious': 1,
#   'songs': 2,
#   'step': 1,
#   'de': 1,
#   'back': 3,
#   'hemanta': 1,
#   'ruud': 1,
#   'ths': 1,
#   'repent': 1,
#   '157': 1,
#   'stuck': 1,
#   'armistead': 1,
#   'lagaylia': 1,
#   'don': 4,
#   'm-cabi': 1,
#   'beijing': 2,
#   'fabri': 2,
#   'stephen': 1,
#   'vintage': 1,
#   'hatfield': 1,
#   'tour': 1,
#   'dickey': 1,
#   'atticus': 2,
#   'madman': 1,
#   'chas': 1,
#   'let': 1,
#   'be': 1,
#   'sara': 2,
#   'jonathan': 1,
#   'mary': 1,
#   'd-day': 1,
#   'vikku': 1,
#   'bossa': 1,
#   'brad': 1,
#   'od': 1,
#   'cream': 1,
#   'take': 2,
#   'histoire': 1,
#   'in': 2,
#   'grim': 1,
#   'jennie': 1,
#   'dias': 1,
#   'candlelight': 1,
#   'us': 1,
#   'mayya': 1,
#   'robin': 4,
#   'olympia': 1,
#   'funtwo': 1,
#   'kevin': 2,
#   'ricky': 1,
#   'ronnie': 1,
#   'i': 7,
#   'jency': 1,
#   'munia': 1,
#   'robyn': 1,
#   'enduser': 1,
#   'koichi': 1,
#   'little': 3,
#   'riddim': 1,
#   'nib': 1,
#   'autry': 1,
#   'rock': 1,
#   'tara': 1,
#   'dave': 2,
#   'splendido': 1,
#   'bring': 1,
#   'shangri-la': 1,
#   'embryo': 1,
#   'best': 1,
#   'kool': 1,
#   'current': 2,
#   'om': 1,
#   'bill': 1,
#   'ray': 1,
#   'giancarlo': 1,
#   'bad': 1,
#   'tatico': 1,
#   'warpaint': 1,
#   'radhae': 1,
#   'teenager': 1,
#   'dean': 1,
#   '3': 1,
#   'nyoil': 1,
#   'sp': 1,
#   'bob': 1,
#   'roger': 1,
#   'francesco': 2,
#   'sarah': 1,
#   'third': 1,
#   'aprite': 2,
#   'alexia': 1,
#   'nina': 1,
#   'secrets': 1,
#   'karin': 1,
#   'jenifer': 1,
#   'josephine': 1,
#   'name': 2,
#   'transmission': 1,
#   'slave': 1,
#   'intelligence': 1,
#   'chamberlain': 1,
#   'totally': 1,
#   'shame': 1,
#   'cake': 1,
#   'young': 1,
#   'please': 1,
#   'refrain': 1,
#   'bashful': 1,
#   'pangaea': 1,
#   'hello': 3,
#   'twin': 1,
#   'el': 4,
#   'matthew': 1,
#   'leah': 1,
#   'house': 2,
#   'sweet': 1,
#   'out': 1,
#   'justin': 1,
#   'afdlin': 1,
#   'roots': 1,
#   'stephanie': 2,
#   'people': 1,
#   'git': 1,
#   'kaya': 1,
#   'come': 2,
#   'kansas': 1,
#   'farruko': 1,
#   'jarvis': 1,
#   'lisa': 3,
#   'barry': 1,
#   'zombieland': 1,
#   'warm': 1,
#   'kasey': 1,
#   'shake': 1,
#   'arthur': 2,
#   'priscilla': 1,
#   'ghost': 1,
#   'jonny': 1,
#   'when': 2,
#   'josefina': 1,
#   'heat': 1,
#   'joey': 1,
#   'first': 1,
#   'natasha': 1,
#   'erik': 1,
#   'what': 3,
#   'already': 1,
#   'jacob': 1,
#   'dark': 1,
#   'iemand': 1,
#   'new': 2,
#   'ultimatum': 1,
#   'alexandra': 1,
#   'metal': 2,
#   'apathy': 1,
#   'cher': 1,
#   'un': 1,
#   'perfect': 1,
#   'louis': 1,
#   'janie': 1,
#   'garry': 1,
#   'shi': 1,
#   'gary': 2,
#   'dj': 1,
#   'kiara': 1,
#   'tinker': 1,
#   'crying': 1,
#   'jason': 1,
#   'tunnel': 2,
#   'nazad': 1,
#   'my': 8,
#   'munawar': 1,
#   'maggie': 1,
#   'suffer': 1,
#   'jermaine': 1,
#   'knocked': 1,
#   'even': 1,
#   'madlib': 1,
#   'bone': 1,
#   'geschwisterliebe': 1,
#   'iene': 1,
#   'hanging': 2,
#   'wing': 1,
#   'tolmatschowa': 1,
#   'time': 1,
#   'hind': 1,
#   'night': 1,
#   'fuzzy': 1,
#   'george': 4,
#   'tapper': 1,
#   'tarja': 1,
#   'curious': 1,
#   'jovanotti': 1,
#   'diarios': 1,
#   'psycho': 1,
#   'love': 1,
#   'sheila': 2,
#   'shelby': 1,
#   '12': 1,
#   'lunacy': 1,
#   'falcon': 1,
#   'tony': 2,
#   'manuelita': 2,
#   'beverley': 1,
#   'sveta': 1,
#   'chen': 1,
#   'butterfly': 1,
#   'thomas': 2,
#   'teddy': 1,
#   'nightmares': 1,
#   'ronski': 1,
#   'jon': 1,
#   'put': 1,
#   'saxophone': 1,
#   'there': 1,
#   'big': 2,
#   'bright': 1,
#   'rakim': 1,
#   'john': 4,
#   'mark': 1,
#   'lari': 1,
#   'gregory': 1,
#   'go': 1,
#   'javine': 1,
#   'mike': 2,
#   'troy': 2,
#   'marching': 1,
#   'bedroom': 1,
#   'judge': 1,
#   'histoires': 1,
#   'adele': 1,
#   'iris': 1,
#   'sabrina': 1,
#   'deus': 1,
#   'kloden': 1,
#   'marianne': 1,
#   'omoide': 1,
#   'sam': 3,
#   'ojuelegba': 1,
#   'puzzles': 1,
#   'xsuie': 1,
#   'tsubasa': 1,
#   'heresy': 1,
#   'singing': 1,
#   'devil': 1,
#   'ivan': 1,
#   'jamaica': 1,
#   'shooter': 1,
#   'joan': 1,
#   'seek': 1,
#   'count': 1,
#   'camille': 1,
#   'jeanette': 1,
#   'sirusho': 1,
#   'child': 1,
#   'family': 1,
#   'bonga': 1,
#   'fra': 1,
#   'mg': 1,
#   'novedades': 1,
#   'tarte': 1,
#   'jeff': 1,
#   'impossible': 1,
#   'morten': 1,
#   'chrome': 1,
#   'cecil': 1,
#   'andreas': 1,
#   'kenneth': 1,
#   'every': 1,
#   'bert': 1,
#   'star': 1,
#   'agua': 1,
#   'jerry': 1,
#   'antisleep': 1,
#   'heart': 1,
#   'fish': 1,
#   'hotter': 1,
#   'scarred': 1,
#   'born': 1,
#   'inconfundible': 2,
#   'me': 1,
#   'cross': 1,
#   'naseer': 1,
#   'barbara': 1,
#   'falling': 2,
#   'waltz': 1,
#   'hallucinations': 1,
#   'irving': 1,
#   '80s': 1,
#   'luiza': 1,
#   'see': 1,
#   'unreachable': 1,
#   'woman': 1,
#   'nour': 1,
#   'naomi': 1,
#   'petar': 1,
#   'give': 1,
#   'venedig': 1,
#   'rodriguez': 1,
#   'richard': 1,
#   'madchild': 1,
#   'manos': 1,
#   'keine': 1,
#   'checkmate': 1,
#   'image': 1,
#   'der': 1,
#   'post': 1,
#   'one': 2,
#   'joe': 3,
#   'if': 1,
#   'pittsburgh': 1,
#   'share': 1,
#   'als': 1,
#   'maki': 1,
#   'testifying': 1,
#   'east': 1,
#   'sin': 1,
#   'daigo': 1,
#   'armand': 1,
#   'paula': 1,
#   'mel': 1,
#   'a-hunting': 1,
#   'welcome': 3,
#   'htoo': 1,
#   'kd': 1,
#   'pimp': 1,
#   'dahmer': 1,
#   'undressed': 1,
#   'dr': 2,
#   'ashley': 2,
#   'steel': 1,
#   'abrar': 1,
#   'mr': 1,
#   'halfway': 1,
#   'died': 1,
#   'moby': 1,
#   'elkie': 1,
#   'la': 3,
#   'jalal': 1,
#   'salil': 1,
#   'o': 1,
#   'now': 1,
#   'por': 2,
#   'scarlet': 1,
#   'fabrice': 1,
#   'blowfly': 1,
#   'bulat': 1,
#   'toi': 1,
#   'classic': 1,
#   'potje': 1,
#   'all': 3,
#   'harlow': 1,
#   'dear': 1,
#   'megon': 1,
#   'det': 1,
#   'through': 1,
#   'tracy': 1,
#   'cut': 1,
#   'trina': 1,
#   'amir': 1,
#   '21': 1,
#   'your': 1,
#   '2012': 1,
#   'raisins': 1,
#   'yameen': 1,
#   'strong': 1,
#   'adam': 1,
#   'teriazume': 1,
#   'chong': 1,
#   'pete': 1,
#   'godmusic': 1,
#   'digital': 1,
#   'sorrow': 1,
#   'from': 1,
#   'ilse': 1,
#   'vertexguy': 1,
#   'of': 1,
#   'sifow': 1,
#   'fred': 1,
#   'lapponia': 1,
#   'ace': 1,
#   'brian': 3,
#   'chris': 3,
#   'georgetown': 1,
#   'robert': 1,
#   'gabrial': 1,
#   'como': 1,
#   'nitti': 1,
#   'indestructible': 1,
#   'dwele': 1,
#   'list': 1,
#   'julian': 1,
#   'dimitri': 1,
#   'daniel': 1,
#   'shot': 1,
#   'black': 2,
#   'lil': 1,
#   'vicky': 1,
#   'michelle': 1,
#   'banana': 1,
#   'elastic': 1,
#   'moon': 1,
#   'kylie': 1,
#   'armen': 1,
#   'showcase': 1,
#   'yma': 1,
#   'carmel': 1,
#   'licorice': 1,
#   'danny': 1,
#   'igor': 1,
#   'space': 1,
#   'rev-raptor': 1,
#   'keltech': 1,
#   'anna': 1,
#   'bilal': 1,
#   'rattus': 1,
#   'zos': 1,
#   'dying': 1,
#   'exorcising': 1,
#   'xenomania': 1,
#   'curse': 1,
#   'you': 1,
#   'rise': 1,
#   'pacific': 1,
#   'desert': 1,
#   'irish': 1,
#   'peter': 1,
#   'zamiast': 1,
#   'wastedagain': 1,
#   'tarkan': 1,
#   'glory': 1,
#   'wes': 1,
#   'deuce': 1,
#   'entre': 1,
#   'party': 1,
#   'appreciation': 1,
#   'however': 1,
#   'foreign': 1,
#   'inca': 1,
#   'animal': 1,
#   'vyechnyy': 1,
#   'contact': 1,
#   'entity': 1,
#   'bronislau': 1,
#   'karusellen': 1,
#   'roel': 1,
#   'shahrum': 1,
#   'opus': 1,
#   'happy': 1,
#   'genocide': 1,
#   'aira': 1,
#   'magnifico': 1,
#   'keke': 1,
#   'hot': 1,
#   'emanuel': 1,
#   'hound': 1,
#   'ihsahn': 1,
#   'jim': 1,
#   'rosemary': 1,
#   'tsidii': 1,
#   'blag': 1,
#   'etta': 1,
#   'paper': 1,
#   'top': 1,
#   'fair': 1,
#   'scott': 1,
#   'coordinates': 1,
#   'great': 1,
#   'reggaeton': 1,
#   'maschi': 1,
#   'decadas': 1,
#   'split': 1,
#   'bien': 1,
#   'concrete': 1,
#   'xiang': 1,
#   'broken': 1,
#   'cleo': 1,
#   'villotta': 1,
#   'anti': 1,
#   'omnipresent': 1,
#   '9am': 1,
#   'raz': 1,
#   'mariem': 1,
#   'pat': 1,
#   'picasso': 1,
#   'hopeful': 1,
#   'anson': 1,
#   'frank': 1,
#   'rmx': 1,
#   'sunday': 1,
#   'faccetta': 1,
#   'patti': 1,
#   'annette': 1,
#   'banking': 1,
#   'without': 1,
#   'johnny': 1,
#   'maria': 1,
#   'baby': 1,
#   'defined': 1,
#   'bret': 1,
#   'honey': 1,
#   'women': 1,
#   'revolution': 1,
#   'day': 1,
#   'zion': 1,
#   'ava': 1,
#   'daedelus': 1,
#   'julia': 1,
#   'blue': 1,
#   'ksiega': 1,
#   'visible': 1,
#   'cary': 1,
#   'up': 1,
#   'los': 1,
#   'driven': 1,
#   'boyce': 1,
#   'circus': 1,
#   'get': 1,
#   'halley': 1,
#   'nico': 1,
#   'september': 1,
#   'grey': 1,
#   'cliffs': 1,
#   'willie': 1,
#   'yang': 1,
#   'spirit': 1,
#   'sci-fi': 1,
#   'unconscious': 1,
#   'warning': 1,
#   'rob': 1,
#   'so': 1,
#   'venetian': 1,
#   'theater': 1,
#   'yoshiki': 1,
#   'dan': 1,
#   'lene': 1,
#   'christopher': 1,
#   'geminism': 1,
#   'owen': 1,
#   'doing': 1,
#   'milas': 1,
#   'lee': 1,
#   'paloma': 1,
#   'must': 1,
#   'mc': 1,
#   'joshua': 1,
#   'art': 1,
#   'bryan': 1,
#   'run': 1,
#   'eylem': 1,
#   'rak': 1,
#   'fear': 1,
#   'r': 1,
#   'sugarolly': 1,
#   'future': 1,
#   'monster': 1,
#   'changes': 1,
#   'tim': 1,
#   'guy': 1,
#   'outside': 1,
#   'that': 1,
#   'philip': 1,
#   'kisaki': 1,
#   'volver': 1,
#   'flying': 1,
#   'sweets': 1,
#   'ana': 1,
#   'decade': 1,
#   'rating': 1,
#   'five': 1},
#  'another': {'song': 12,
#   'artist': 7,
#   'tune': 11,
#   'album': 9,
#   'track': 6,
#   'glass': 2,
#   'mc': 1,
#   'ball': 1,
#   'girl': 1,
#   'planet': 1,
#   'life': 1,
#   'end': 1,
#   'cinderella': 1,
#   'time': 1,
#   'way': 1,
#   'period': 1,
#   'happy': 1,
#   'ticket': 1,
#   'picture': 1},
#  'song': {'to': 111,
#   'list': 2,
#   'by': 75,
#   'onto': 10,
#   'on': 21,
#   '.': 4,
#   'in': 16,
#   'about': 1,
#   'do': 1,
#   'from': 49,
#   'added': 2,
#   'is': 2,
#   'into': 1,
#   'get': 1,
#   'playing': 1,
#   'aspro': 1,
#   'gangsta': 1,
#   'heartful': 1,
#   'released': 1,
#   'book': 1,
#   'victim': 1,
#   'for': 3,
#   'si': 1,
#   'i': 1,
#   'off': 7,
#   'form': 1,
#   'little': 1,
#   'remains': 1,
#   'waar': 1,
#   'that': 1,
#   'of': 5,
#   'shine': 1,
#   'long': 1,
#   'drifting': 1,
#   'white': 1,
#   'vodka': 1,
#   'american': 2,
#   'fro': 1,
#   'fair': 1,
#   'domino': 1,
#   'two': 1,
#   'le': 1,
#   'jingle': 1,
#   'called': 11,
#   'first': 1,
#   'ufo': 1,
#   'only': 1,
#   'daimidaler': 1,
#   'black': 1,
#   'occasional': 1,
#   'schedule': 2,
#   'a': 1,
#   'visual': 1,
#   'banquet': 1,
#   '15': 1,
#   'sit': 1,
#   'culture': 1,
#   '2': 1,
#   'red': 2,
#   'memories': 1,
#   'the': 8,
#   '?': 3,
#   'tholireyi': 1,
#   'ticks': 1,
#   'titled': 2,
#   'evocation': 1,
#   'house': 1,
#   's.f.': 1,
#   'bleach': 1,
#   'aap': 1,
#   'impractical': 1,
#   'just': 1,
#   ',': 1,
#   'spiderman': 1,
#   'softly': 1,
#   'shamus': 1,
#   'phrazes': 1,
#   'aura': 1,
#   'goes': 1},
#  'to': {'the': 362,
#   'trapeo': 1,
#   'my': 817,
#   'cleaning': 3,
#   'playlist': 13,
#   'dena': 1,
#   'sleepytime': 1,
#   'year': 2,
#   'trad': 1,
#   'laurie': 1,
#   'queen': 2,
#   'virginia': 1,
#   'put': 18,
#   'noreen': 2,
#   'rock': 9,
#   'downtempo': 2,
#   'calm': 2,
#   'listas': 1,
#   'latin': 7,
#   'krystal': 1,
#   'workout': 3,
#   'cristina': 1,
#   'laundry': 4,
#   'this': 73,
#   'ashlee': 1,
#   'ines': 1,
#   'night': 1,
#   'it': 3,
#   'feeling': 1,
#   'sxsw': 4,
#   'todo': 3,
#   'corinne': 2,
#   'add': 61,
#   'meditate': 1,
#   'sounds': 2,
#   'women': 12,
#   'brooklyn': 3,
#   'st': 1,
#   'afternoon': 1,
#   'teh': 1,
#   'country': 2,
#   'instrumental': 4,
#   'electronic': 2,
#   'inez': 1,
#   'halloween': 1,
#   'electronow': 3,
#   'diann': 1,
#   'joann': 1,
#   'you': 4,
#   'power': 7,
#   'hit': 3,
#   'retrowave': 1,
#   'atmospheric': 1,
#   'ultra': 3,
#   'i': 4,
#   'metal': 3,
#   'a': 44,
#   'under': 1,
#   'lo': 8,
#   'me': 10,
#   'kickass': 1,
#   'classical': 4,
#   'leticia': 1,
#   'composer': 1,
#   'blues': 5,
#   'in': 1,
#   'sos': 1,
#   'evening': 2,
#   'escapada': 2,
#   'marina': 1,
#   'confidence': 2,
#   'have': 6,
#   '90s': 3,
#   'spain': 2,
#   'feelin': 1,
#   'trap': 2,
#   'soft': 1,
#   'indiespain': 1,
#   'dubstep': 1,
#   'your': 6,
#   'siesta': 1,
#   'dear': 1,
#   'infinite': 1,
#   'funtime': 1,
#   'punk': 9,
#   'duetos': 2,
#   'from': 1,
#   'chicago': 1,
#   'rocksteady': 1,
#   'disco': 2,
#   'isabella': 1,
#   'die': 4,
#   'crate': 1,
#   'whm': 1,
#   'ora': 1,
#   'fay': 1,
#   'patrica': 1,
#   'be': 161,
#   'new': 4,
#   'teddy': 1,
#   'lessie': 1,
#   'wild': 4,
#   'mellow': 2,
#   'daily': 2,
#   'organica': 1,
#   'cynthia': 1,
#   'highway': 1,
#   'rhythm': 2,
#   'la': 3,
#   'zen': 1,
#   'gayle': 1,
#   'funky': 1,
#   'essential': 1,
#   'cassie': 1,
#   'acoustic': 5,
#   'sing': 4,
#   'skatepark': 1,
#   'like': 4,
#   'bake': 1,
#   'club': 1,
#   'rosanna': 1,
#   'novedades': 3,
#   'cali': 1,
#   'love': 7,
#   'anne': 1,
#   'indie': 4,
#   'sleep': 1,
#   'fusion': 2,
#   'wedding': 1,
#   'an': 7,
#   'domingo': 1,
#   'crossroad': 1,
#   'stress': 1,
#   'ina': 2,
#   'reggae': 2,
#   'exitos': 1,
#   'noctambulo': 1,
#   'holly': 1,
#   'daphne': 1,
#   'summer': 1,
#   'isabelle': 1,
#   'bandas': 2,
#   'dark': 1,
#   'hip': 3,
#   'rumba': 1,
#   'clasicos': 2,
#   'nusic': 1,
#   'arlene': 1,
#   'meredith': 1,
#   'edna': 1,
#   'showstopper': 1,
#   '190': 3,
#   'marta': 1,
#   'jazz': 2,
#   'top': 1,
#   'travelling': 1,
#   'spring': 2,
#   'dorothea': 1,
#   '1975': 4,
#   'all': 4,
#   'move': 2,
#   'build': 1,
#   'morning': 3,
#   'piano': 2,
#   'clarice': 1,
#   'canciones': 1,
#   'deep': 1,
#   'street': 1,
#   'alternative': 1,
#   'classic': 3,
#   'ultimate': 2,
#   'nu': 1,
#   'virales': 1,
#   'michael': 1,
#   'sweet': 1,
#   'rapcaviar': 1,
#   'send': 2,
#   'ann': 2,
#   'ofelia': 1,
#   'electro': 2,
#   'primavera': 1,
#   'genuine': 1,
#   'miami': 1,
#   'album': 1,
#   'come': 1,
#   'ila': 1,
#   'sheri': 1,
#   'dance': 2,
#   'june': 1,
#   'trabajo': 2,
#   'rena': 1,
#   'running': 1,
#   'sin': 1,
#   'journey': 1,
#   'jazzy': 1,
#   'extreme': 1,
#   'conexiones': 1,
#   'autumn': 2,
#   'spa': 1,
#   'skylar': 1,
#   'princesas': 1,
#   'madden': 1,
#   'work': 2,
#   'digster': 3,
#   'pop': 3,
#   'fresh': 3,
#   'hallie': 1,
#   'cierra': 1,
#   'propuesta': 1,
#   'stomp': 1,
#   'guest': 1,
#   'alejandra': 1,
#   'just': 2,
#   'thrash': 1,
#   'ethel': 1,
#   'lakeisha': 1,
#   'sunshine': 1,
#   'lora': 1,
#   'workday': 1,
#   'dinner': 1,
#   'vonda': 1,
#   'kristine': 1,
#   'one': 4,
#   'pure': 1,
#   'donna': 1,
#   'indietronic': 1,
#   'go': 38,
#   'fifa': 1,
#   'deathcore': 2,
#   'hiphop': 2,
#   'lina': 1,
#   'life': 3,
#   'enamorandose': 2,
#   'happy': 1,
#   'winnie': 1,
#   'folk': 1,
#   'mujeres': 1,
#   'retro': 2,
#   'decadas': 1,
#   'concentracion': 2,
#   'he': 1,
#   'late': 1,
#   'latoya': 1,
#   '90': 1,
#   'rare': 1,
#   'nacao': 1,
#   'johnnie': 1,
#   'jannie': 1,
#   'old': 1,
#   'urban': 2,
#   'frescura': 1,
#   'is': 1,
#   'winifred': 1,
#   'california': 1,
#   'beach': 1,
#   'el': 2,
#   'bajo': 1,
#   'road': 1,
#   'trotamundos': 1,
#   'gretchen': 1,
#   'marguerite': 1,
#   'tgif': 1,
#   'lush': 1,
#   'feminist': 1,
#   'lunchtime': 1,
#   'myra': 1,
#   'peace': 2,
#   'sharlene': 1,
#   'canadian': 1,
#   'winter': 2,
#   'african': 1,
#   'mas': 1,
#   'bedroom': 1,
#   'joy': 1,
#   'operacion': 1,
#   'psychedelic': 2,
#   'kids': 2,
#   'romantica': 1,
#   'jenifer': 1,
#   'verano': 2,
#   'phunkadelic': 1,
#   'taylor': 1,
#   'juliana': 1,
#   'enid': 1,
#   'maryanne': 1,
#   'baroque': 1,
#   'michele': 1,
#   'pamela': 1,
#   'pura': 2,
#   'anochecer': 1,
#   'orgullo': 1,
#   'bass': 1,
#   'anacreon': 1,
#   'black': 1,
#   'tania': 1,
#   'tameka': 1,
#   'llegando': 1,
#   'maritza': 1,
#   'esenciales': 1,
#   'solo': 1,
#   'drive': 2,
#   'hillary': 1,
#   'judy': 1,
#   'epic': 1,
#   'janell': 1,
#   '80': 1,
#   'poetry': 1,
#   'chillin': 1,
#   'te': 1,
#   'hits': 1,
#   'odetta': 1,
#   'evangeline': 1,
#   'abigail': 1,
#   'tears': 1,
#   'cherry': 2,
#   'geraldine': 2,
#   'betsy': 1,
#   'hipster': 1,
#   'forever': 2,
#   'reyna': 1,
#   'string': 1,
#   'viajes': 1,
#   'chill': 2,
#   'hot': 1,
#   'enjoy': 2,
#   'millicent': 1,
#   'family': 1,
#   'relaxing': 1,
#   'eat': 107,
#   'book': 181,
#   'antigua': 1,
#   'reserve': 10,
#   'that': 1,
#   'get': 37,
#   'accommodate': 5,
#   'dekalb': 1,
#   'find': 47,
#   'take': 11,
#   'make': 8,
#   'pelham': 1,
#   'alabama': 1,
#   'guinea-bissau': 1,
#   'dine': 4,
#   'bowlegs': 1,
#   '88th': 1,
#   'grenada': 1,
#   'visit': 2,
#   'westhampton': 1,
#   'dillard': 1,
#   'smith-9th': 1,
#   'bring': 4,
#   'seat': 1,
#   'ottumwa': 1,
#   'our': 1,
#   'downtown': 1,
#   'grant': 1,
#   'herkimer': 1,
#   'astor': 1,
#   'broadway-lafayette': 1,
#   'westfield': 1,
#   'food': 1,
#   'far': 1,
#   'check': 1,
#   'rain': 6,
#   'know': 23,
#   'cambodia': 1,
#   'dukes': 1,
#   'hollidaysburg': 1,
#   'ukraine': 1,
#   'ten': 1,
#   'windber': 1,
#   'crimson': 1,
#   'blizzard': 1,
#   'nimule-nationalpark': 1,
#   'hail': 4,
#   'bailey': 1,
#   'romania': 1,
#   'storm': 2,
#   'texas': 1,
#   'jolley': 1,
#   'australia': 1,
#   'somesville': 1,
#   'dc': 1,
#   'gt': 1,
#   'see': 102,
#   'harmar': 1,
#   'snow': 2,
#   'north': 1,
#   'moosic': 1,
#   'stretch': 1,
#   'fern': 1,
#   'puerto': 1,
#   'pakistan': 1,
#   'namibia': 1,
#   'hear': 129,
#   'listen': 45,
#   'born': 1,
#   'play': 65,
#   'rouhollah': 1,
#   'space': 1,
#   'dream': 2,
#   'some': 6,
#   'pmd': 1,
#   'twilight': 1,
#   'roger': 1,
#   'injury': 1,
#   'mary': 1,
#   'lastfm': 1,
#   'seventies': 2,
#   'acapella': 1,
#   'speed': 1,
#   'diana': 1,
#   'meditative': 1,
#   '.': 1,
#   'opera': 1,
#   'nineties': 1,
#   'iheart': 1,
#   'tei': 1,
#   'dj': 1,
#   'merrily': 1,
#   'chara': 1,
#   'heaven': 3,
#   'vertexguy': 1,
#   'good': 1,
#   'ballad': 2,
#   'westbam': 1,
#   'merengue': 1,
#   'eighties': 1,
#   'music': 2,
#   'tiny': 1,
#   'swing': 1,
#   'tom': 1,
#   'absolutely': 1,
#   'dickson': 1,
#   'rate': 28,
#   'current': 40,
#   'she': 1,
#   'give': 56,
#   'who': 1,
#   'short': 1,
#   'remember': 2,
#   'last': 1,
#   'scribblings': 1,
#   '6': 8,
#   'december': 1,
#   'harlem': 1,
#   'reality': 2,
#   'creatures': 1,
#   'waiting': 1,
#   'empire': 1,
#   'live': 1,
#   'chronicle': 1,
#   'prism': 1,
#   'tomorrow': 1,
#   'marxism': 1,
#   'darkworld': 1,
#   'myths': 1,
#   'what': 2,
#   'fear': 1,
#   'arranged': 1,
#   'mulligan': 1,
#   'fight': 1,
#   'religion': 1,
#   'ecosystems': 1,
#   'compendium': 1,
#   'smart': 1,
#   'mr': 1,
#   'khaled': 1,
#   'may': 1,
#   'leven': 1,
#   'foo': 1,
#   'beyond': 1,
#   'blackbox': 1,
#   'save': 1,
#   'racing': 1,
#   'kill': 3,
#   'global': 1,
#   'high': 2,
#   'encyclopedia': 1,
#   'memory': 1,
#   'free': 1,
#   'expressive': 1,
#   'mystery': 1,
#   'war': 1,
#   'doctor': 1,
#   'house': 1,
#   'west': 1,
#   'lincoln': 1,
#   '3': 1,
#   'smoke': 1,
#   'confessions': 1,
#   'thorn': 1,
#   'as': 1,
#   'talbot': 1,
#   'practice': 1,
#   'deceive': 1,
#   'coming': 1,
#   'revolution': 1,
#   'watch': 91,
#   'buy': 7,
#   'read': 11,
#   'stop': 1,
#   'meet': 1,
#   'glory': 1,
#   'consume': 1,
#   'wear': 1,
#   'hide': 1,
#   'midnight': 3,
#   'handle': 1,
#   'abuja': 1,
#   'successful': 1,
#   'dragon': 1,
#   'attack': 1,
#   'boomtown': 1,
#   'senkyo': 1,
#   'chocolate': 1,
#   'danger': 1,
#   'evil': 1,
#   'south': 1,
#   'astronomy': 1,
#   'marry': 4,
#   'worms': 1,
#   'view': 1,
#   'eternity': 1,
#   'bioruby': 1,
#   'georgia': 1,
#   'episodes': 1,
#   'do': 1,
#   'keep': 1,
#   'bach': 1,
#   'grace': 1,
#   'fins': 1,
#   'hickory': 1,
#   'after': 1,
#   'willy': 1,
#   'aise': 1,
#   'tokyo': 1,
#   'time': 1,
#   'krondor': 1,
#   'beer': 1,
#   'paris': 1,
#   'heart': 1,
#   'each': 1,
#   'world': 1,
#   'draw': 1,
#   'melbourne': 1,
#   'billy': 1,
#   'moko': 1,
#   'death': 1,
#   'mir': 1,
#   'movie': 2,
#   'shoot': 1,
#   'us': 1,
#   'john': 1,
#   'moment': 1,
#   'freedom': 1,
#   'strike': 1,
#   'to': 1,
#   'commit': 1,
#   'douglas': 1,
#   'start': 1,
#   'darwin': 1,
#   'yesterday': 1},
#  'the': {'cita': 1,
#   'piano': 7,
#   'house': 8,
#   'greyest': 1,
#   'name': 29,
#   'street': 4,
#   'plylist': 1,
#   'latin': 2,
#   'dcode2016': 1,
#   'new': 23,
#   'fire': 4,
#   'wind': 7,
#   'playlist': 79,
#   'album': 91,
#   'psychedelic': 1,
#   'sleep': 5,
#   'boss': 2,
#   'this': 13,
#   'warm': 2,
#   'queen': 7,
#   'artist': 49,
#   'passion': 5,
#   'show': 52,
#   'selektor': 5,
#   'button': 1,
#   'martin': 7,
#   'orange': 1,
#   'green': 6,
#   'steampunk': 2,
#   'face': 2,
#   'spring': 4,
#   'conexiones': 2,
#   'a': 4,
#   'rockin': 1,
#   'hit': 2,
#   'hot': 4,
#   'top': 44,
#   'classical': 2,
#   'all': 6,
#   'silence': 2,
#   'dubstep': 2,
#   'spine': 1,
#   'funny': 4,
#   'fantasia': 2,
#   'entity': 3,
#   'song': 79,
#   'title': 12,
#   'indiespensables': 1,
#   'r': 1,
#   '90s': 2,
#   'road': 7,
#   'tune': 14,
#   'indie': 2,
#   'edge': 6,
#   '3rd': 4,
#   'deep': 6,
#   'midnight': 4,
#   '90': 1,
#   'cafe': 1,
#   'laundry': 1,
#   'keep': 2,
#   'plague': 3,
#   'ntc': 1,
#   'surface': 5,
#   'relaxing': 1,
#   'hip': 2,
#   '50': 3,
#   'sunshine': 2,
#   'velvet': 1,
#   'city': 25,
#   'storm': 6,
#   'electrosafari': 2,
#   'stars': 10,
#   'soulful': 1,
#   '2010': 1,
#   'unraveling': 1,
#   'bachelor': 3,
#   'another': 2,
#   'background': 4,
#   'north': 4,
#   'roadrunner': 1,
#   'block': 2,
#   'soil': 1,
#   'season': 1,
#   '70s': 3,
#   'electro': 1,
#   'bajo': 1,
#   'pumping': 1,
#   'metalsucks': 4,
#   'korean': 1,
#   'funk': 2,
#   'mood': 2,
#   'de': 2,
#   'nastya': 1,
#   'signed': 1,
#   'delta': 1,
#   'enamorandose': 1,
#   '80s': 3,
#   'get': 1,
#   'tale': 3,
#   'french': 6,
#   'blurred': 1,
#   'beatles': 1,
#   'southern': 3,
#   'lady': 8,
#   'rhythm': 3,
#   'towel': 1,
#   'chips': 1,
#   'emily': 2,
#   'outlaw': 1,
#   'african': 1,
#   'phunkadelic': 1,
#   'motivation': 1,
#   'singer': 6,
#   'leche': 2,
#   'rock': 3,
#   'da': 2,
#   'soak': 1,
#   'sun': 12,
#   'spa': 5,
#   'concentracion': 2,
#   'alibi': 1,
#   'soundtrack': 28,
#   '2000': 2,
#   'big': 10,
#   'night': 16,
#   'songs': 3,
#   'car': 4,
#   'park': 4,
#   'novedades': 1,
#   'wine': 2,
#   'air': 4,
#   'outsiders': 1,
#   'soul': 5,
#   'current': 327,
#   'water': 3,
#   'lemonheads': 1,
#   'world': 22,
#   'blues': 4,
#   'acoustic': 2,
#   'refugee': 3,
#   'end': 6,
#   'feel': 2,
#   'track': 24,
#   'dead': 6,
#   'ironing': 1,
#   'el': 2,
#   'dance': 3,
#   'spinnin': 1,
#   'best': 67,
#   'jazz': 2,
#   'joy': 2,
#   'complete': 5,
#   'ragged': 1,
#   'decades': 4,
#   'romantica': 1,
#   'kitchen': 3,
#   'grind': 1,
#   'birth': 4,
#   'other': 3,
#   'still': 2,
#   'white': 10,
#   'man': 12,
#   'pulse': 3,
#   'friendesemana': 1,
#   "'chirping": 1,
#   'pre-party': 2,
#   'irish': 1,
#   'dancefloor': 1,
#   'chill': 3,
#   'executioner': 1,
#   'black': 15,
#   'trapaholics': 1,
#   'cool': 4,
#   'rapcaviar': 1,
#   'frank': 1,
#   'soft': 2,
#   'jazzy': 1,
#   'currently': 1,
#   'sexy': 1,
#   'soundscapes': 1,
#   'lamb': 1,
#   'evening': 3,
#   'dub': 1,
#   'beach': 4,
#   'rebirth': 1,
#   'fiesta': 1,
#   'club': 1,
#   'pop': 3,
#   'spotlight': 2,
#   'decadas': 1,
#   'infinite': 2,
#   'cloud': 4,
#   'cena': 2,
#   'sea': 13,
#   'puppet': 2,
#   'little': 7,
#   'eulogy': 1,
#   'sylvia': 1,
#   'entire': 1,
#   'heavy': 1,
#   'traces': 1,
#   'essential': 1,
#   'family': 3,
#   'grime': 2,
#   'nanette': 1,
#   'hotel': 1,
#   'trees': 1,
#   'dinner': 4,
#   'dio': 1,
#   'visionary': 1,
#   'spanish': 2,
#   'para': 1,
#   'digster': 1,
#   'pure': 2,
#   'funtime': 1,
#   'gaslight': 2,
#   'nuclear': 2,
#   'proof': 1,
#   'cardio': 1,
#   'hellacopters': 1,
#   'metal': 4,
#   'n': 1,
#   'power': 6,
#   'field': 1,
#   'metalcore': 1,
#   'focus': 1,
#   'maid': 1,
#   'well': 2,
#   'rough': 2,
#   'music': 17,
#   'ozzy': 2,
#   'turbonegro': 1,
#   'burgermeister': 1,
#   'cruel': 3,
#   'chamillionaire': 1,
#   'mash': 2,
#   'crowd': 4,
#   'laugh': 1,
#   'old': 6,
#   'medieval': 1,
#   'todo': 1,
#   'hits': 2,
#   'tennessee': 2,
#   'kids': 3,
#   'classic': 1,
#   'happy': 3,
#   'years': 2,
#   'trad': 1,
#   'darkness': 2,
#   'zen': 1,
#   'second': 10,
#   'uncharted': 1,
#   'spirit': 7,
#   'nacao': 1,
#   'cave': 2,
#   'magnificent': 2,
#   'gospel': 1,
#   'tim': 1,
#   'ashes': 1,
#   'secret': 9,
#   'digging': 1,
#   'country': 9,
#   'crabfish': 1,
#   'ultimate': 6,
#   'autumn': 1,
#   'broken': 3,
#   'workout': 1,
#   'dias': 1,
#   'trapeo': 1,
#   'frl': 1,
#   'chillin': 1,
#   'perfect': 4,
#   'roundhouse': 1,
#   'under': 3,
#   'lo-fi': 1,
#   'days': 4,
#   'patty': 1,
#   'i': 2,
#   'infidels': 1,
#   'kickass': 1,
#   'wild': 7,
#   'trey': 1,
#   'highest': 1,
#   'feeling': 1,
#   'state': 9,
#   'disney': 1,
#   'party': 4,
#   'emo': 1,
#   'drive': 2,
#   'drum': 2,
#   'sin': 1,
#   'women': 4,
#   'wee': 1,
#   'miami': 1,
#   'the': 8,
#   'open': 2,
#   'bill': 1,
#   'avispa': 1,
#   'we': 2,
#   'airi': 1,
#   'mike': 1,
#   'difference': 1,
#   'darkest': 2,
#   'heart': 5,
#   'epic': 2,
#   'go': 1,
#   'time': 5,
#   'arms': 3,
#   'te': 2,
#   'scratchy': 1,
#   'inner': 1,
#   'love': 4,
#   'game': 48,
#   '60s': 1,
#   'century': 1,
#   'massive': 1,
#   'nature': 1,
#   'six': 2,
#   'calm': 1,
#   'mountain': 3,
#   'viral': 1,
#   'private': 3,
#   'summer': 3,
#   'comedy': 1,
#   'war': 5,
#   'fresh': 1,
#   'yumi': 1,
#   'atmospheric': 1,
#   '35': 1,
#   'automator': 1,
#   'past': 3,
#   'lunch': 1,
#   'muppet': 2,
#   'dream': 1,
#   'duetos': 1,
#   'last': 56,
#   'fusion': 1,
#   'same': 75,
#   'middle': 5,
#   'district': 4,
#   'gus': 1,
#   'twenty-sixth': 2,
#   '12th': 2,
#   'oriel': 1,
#   'ledbury': 1,
#   'great': 13,
#   'eighteenth': 2,
#   'sixteenth': 4,
#   'fashion': 2,
#   '11th': 3,
#   '7th': 3,
#   'coffee': 1,
#   'dominican': 4,
#   'pub': 5,
#   'cubby': 2,
#   'highly': 3,
#   'slippery': 1,
#   'boon': 1,
#   'cayman': 3,
#   'freight': 1,
#   '14th': 3,
#   'wolseley': 2,
#   'food': 9,
#   'distant': 5,
#   'crown': 3,
#   'maisonette': 2,
#   'popular': 3,
#   'cocos': 1,
#   'restaurant': 8,
#   'twentieth': 5,
#   'pump': 1,
#   '8th': 6,
#   'halal': 1,
#   'original': 4,
#   'training': 2,
#   'hat': 1,
#   'next': 17,
#   'neighborhood': 72,
#   'week-end': 1,
#   'unseen': 2,
#   'most': 30,
#   'nearby': 3,
#   'hand': 3,
#   'northeast': 1,
#   'taverna': 1,
#   'day': 12,
#   'trout': 1,
#   'marshall': 3,
#   'fry': 1,
#   'brass': 2,
#   'fifth': 7,
#   'beardslee': 1,
#   'bar': 2,
#   'grenadines': 8,
#   'laurelhurst': 1,
#   '9th': 3,
#   'twenty-seventh': 4,
#   'k': 1,
#   'municipal': 2,
#   'dunbrody': 2,
#   'berghoff': 3,
#   'roseland': 1,
#   'bobcat': 2,
#   'union': 1,
#   'kitchin': 1,
#   '13th': 2,
#   'vortex': 1,
#   'tavern': 3,
#   'top-rated': 6,
#   'steakhouse': 1,
#   'oasis': 1,
#   'cheese': 1,
#   '10th': 5,
#   'third': 3,
#   'mustard': 2,
#   'oyster': 1,
#   'rainforest': 1,
#   'first': 7,
#   'twelfth': 4,
#   'area': 71,
#   'sky': 10,
#   'downtown': 1,
#   '1st': 3,
#   'metropolitan': 1,
#   'northern': 4,
#   'fat': 2,
#   'hamburger': 1,
#   'irma': 1,
#   'meatball': 1,
#   'neighboring': 4,
#   'restaurants': 1,
#   'fort': 2,
#   'congo': 3,
#   'venetian': 1,
#   'twenty-third': 5,
#   'kegs': 1,
#   'maldives': 1,
#   'bridge': 3,
#   '16th': 1,
#   'twenty-fourth': 1,
#   'fourth': 3,
#   'octagon': 1,
#   'thirteenth': 7,
#   'american': 9,
#   'tea': 3,
#   'clink': 1,
#   'twenty-eighth': 2,
#   'triple': 1,
#   'san': 1,
#   'space': 1,
#   'fourteenth': 2,
#   'star': 2,
#   'commons': 2,
#   'eighth': 4,
#   'cityzen': 1,
#   'lake': 2,
#   'washington': 1,
#   'light': 3,
#   'nineteenth': 2,
#   'chapter': 1,
#   'labworth': 1,
#   'pool': 2,
#   '6th': 3,
#   'coon': 1,
#   'alley': 2,
#   'georgia': 1,
#   '4th': 2,
#   'ballylickey': 1,
#   'vatican': 1,
#   'brazen': 1,
#   '20th': 3,
#   'spotted': 1,
#   'bakery': 1,
#   '17th': 1,
#   'dalles': 1,
#   'pitcairn': 2,
#   '24th': 3,
#   'nearest': 149,
#   'mark': 4,
#   'crooked': 1,
#   'seventeenth': 2,
#   'ballachulish': 1,
#   'weathervane': 1,
#   'falkland': 4,
#   'internet': 3,
#   'seventh': 2,
#   'atomic': 1,
#   'palm': 1,
#   'montreal': 1,
#   'cherry': 1,
#   'close': 2,
#   'brooklyn': 1,
#   'electric': 1,
#   'dome': 1,
#   'one': 1,
#   '18th': 3,
#   'wwe': 1,
#   '23': 1,
#   'maison': 1,
#   'pizza': 1,
#   'seward': 1,
#   'smoking': 2,
#   'clarke': 1,
#   '15th': 2,
#   'hog': 1,
#   'river': 9,
#   'russia': 1,
#   'firehouse': 1,
#   'tenth': 3,
#   'nosh': 1,
#   'local': 14,
#   'gowanus': 1,
#   'goof': 2,
#   'united': 3,
#   'conflict': 1,
#   'virgin': 1,
#   'bear': 1,
#   'room': 1,
#   'elephant': 1,
#   'solomon': 1,
#   'isle': 2,
#   'counter': 1,
#   'peak': 2,
#   'is': 1,
#   'red': 7,
#   'rosebud': 1,
#   'federated': 3,
#   'twenty-second': 1,
#   'khedive': 1,
#   'apple': 2,
#   'weather': 734,
#   'forecast': 185,
#   'rio': 1,
#   'sri': 1,
#   'predicted': 4,
#   'chilly': 1,
#   'temperate': 7,
#   'wather': 2,
#   'bolsa': 1,
#   'nationalpark': 1,
#   'flight': 3,
#   'forcast': 1,
#   'humidity': 15,
#   'expected': 2,
#   '7': 3,
#   'poland': 1,
#   'niceville': 1,
#   'meal': 1,
#   'currituck': 1,
#   'ak-suu': 1,
#   'depression': 1,
#   'british': 3,
#   'mississippi': 2,
#   'week': 1,
#   'manassas': 1,
#   '00:00': 1,
#   'ninth': 3,
#   'south': 3,
#   '21st': 3,
#   'edward': 1,
#   '28th': 2,
#   'temperature': 9,
#   'jan.': 1,
#   'forecasted': 2,
#   'me': 1,
#   'ivory': 1,
#   'dresden': 1,
#   'faraway': 1,
#   '2nd': 1,
#   'snowfall': 1,
#   'eather': 1,
#   'oct.': 1,
#   'orlovista': 1,
#   'foggy': 1,
#   '27th': 2,
#   'tal': 1,
#   'baotianman': 1,
#   'eleventh': 2,
#   'blizzard': 2,
#   'weathr': 1,
#   'nationaal': 1,
#   'freezing': 1,
#   'future': 4,
#   '22nd': 1,
#   'overcast': 2,
#   'u.s.': 1,
#   'october': 1,
#   'cameia': 1,
#   'fiji': 1,
#   'halfbreed': 1,
#   'pennsylvania': 1,
#   'bothwell': 1,
#   'gearhart': 1,
#   'wauseon': 1,
#   '19th': 1,
#   'rainfall': 1,
#   'midday': 1,
#   'afternoon': 3,
#   'twenty': 2,
#   'calipuy': 1,
#   'fifteenth': 1,
#   'morning': 5,
#   'random': 1,
#   'nh': 1,
#   'pw': 2,
#   'idledale': 1,
#   '25th': 1,
#   'kent': 1,
#   'forecase': 1,
#   'matlacha': 1,
#   'lualualei': 1,
#   '11': 1,
#   'eugene': 1,
#   'apolobamba': 1,
#   '5th': 1,
#   '10': 2,
#   'dominica': 1,
#   'bethany': 1,
#   '23rd': 1,
#   'colder': 1,
#   'netherlands': 2,
#   'mt': 1,
#   'town': 1,
#   'dana': 1,
#   'foreast': 1,
#   'bahamas': 2,
#   'johnson': 1,
#   'wildreservaat': 1,
#   'coulee': 1,
#   'philippines': 2,
#   'posey': 1,
#   'loco': 1,
#   'nine': 2,
#   'thursday': 1,
#   'valley': 3,
#   'cold': 2,
#   'musica': 1,
#   'thirties': 29,
#   'seventies': 17,
#   'newest': 27,
#   'bayou': 1,
#   'twenties': 33,
#   'top-5': 3,
#   'eye': 1,
#   'way': 5,
#   'trail': 1,
#   'lonesome': 1,
#   'fourties': 24,
#   '1992': 1,
#   '1951': 1,
#   'fifties': 16,
#   'eighties': 13,
#   'sixties': 20,
#   'canciones': 1,
#   'top-10': 1,
#   'don': 1,
#   'necromancer': 1,
#   'anheuser': 1,
#   'aj': 1,
#   'cowboy': 1,
#   'estado': 1,
#   'lord': 7,
#   'ammunition': 2,
#   'balance': 2,
#   'nineties': 11,
#   'instrumental': 1,
#   'greatest': 28,
#   'observer': 1,
#   'year': 12,
#   'latest': 18,
#   'bathroom': 1,
#   'happiest': 1,
#   '1976': 1,
#   'rascals': 1,
#   'roses': 2,
#   'concert': 1,
#   'jonathon': 1,
#   'lamentation': 1,
#   'change': 2,
#   'sleepy': 1,
#   'eternal': 2,
#   'service': 6,
#   'symphony': 1,
#   'universe': 5,
#   'sound': 4,
#   'ricky': 2,
#   'fool': 1,
#   'hill': 2,
#   '1991': 1,
#   'jack': 2,
#   'view': 1,
#   'heinz': 1,
#   '2014': 1,
#   'gary': 1,
#   'garden': 2,
#   'theme': 3,
#   'top-20': 3,
#   'hard': 4,
#   'top-twenty': 6,
#   'kleptones': 1,
#   'bonny': 1,
#   'good': 7,
#   'railway': 2,
#   'mother': 1,
#   'kid': 5,
#   'top-ten': 2,
#   'wizard': 5,
#   'top-50': 1,
#   '1966': 1,
#   'mocking': 1,
#   'top-fifty': 2,
#   'nicht': 1,
#   'god': 3,
#   'live': 4,
#   'furious': 1,
#   'busco': 1,
#   'fear': 1,
#   'boom': 1,
#   'cross': 1,
#   'crucible': 2,
#   'stone': 3,
#   'birds': 2,
#   'bees': 2,
#   'late': 5,
#   'noise': 1,
#   'ocelot': 1,
#   '12': 1,
#   'jody': 1,
#   'curtis': 1,
#   'mountains': 2,
#   'squall': 1,
#   'realest': 1,
#   'today': 1,
#   'mister': 1,
#   'planet': 2,
#   'galway': 1,
#   'monkeys': 1,
#   'blue': 6,
#   '2006': 1,
#   '21': 2,
#   'golden': 3,
#   'insoc': 1,
#   'soviet': 1,
#   'genre': 2,
#   'floor': 1,
#   'tyranny': 1,
#   'it': 1,
#   'banshees': 1,
#   'record': 1,
#   'devil': 9,
#   'roches': 1,
#   'slash': 1,
#   'energic': 1,
#   'alchemist': 1,
#   'bishop': 2,
#   'believer': 1,
#   'killers': 1,
#   'vimeo': 1,
#   'charlie': 1,
#   'easy': 2,
#   'punk': 1,
#   'gate': 2,
#   'cherry-tree': 1,
#   '1996': 1,
#   'rave': 1,
#   'top-five': 1,
#   'sunset': 1,
#   'blind': 2,
#   'human': 2,
#   'list': 1,
#   'prairie': 2,
#   'lotus': 2,
#   'ghetto': 1,
#   'fall-down': 1,
#   'ape-man': 1,
#   'penalty': 1,
#   'shadows': 2,
#   'following': 17,
#   'previous': 17,
#   'tropic': 1,
#   'judas': 1,
#   'billion': 1,
#   'skystone': 2,
#   'glory': 1,
#   'cry': 1,
#   'owl': 1,
#   'keys': 1,
#   'saint': 3,
#   'bunce': 1,
#   'book': 127,
#   'watsons': 1,
#   'nile': 2,
#   'gorilla': 1,
#   'chronicle': 17,
#   'tree': 2,
#   'variation': 1,
#   'lacuna': 1,
#   'practice': 1,
#   'presence': 1,
#   'beyond': 2,
#   'english': 4,
#   'series': 8,
#   'voyage': 1,
#   'dawn': 5,
#   'sunrise': 1,
#   'rim': 1,
#   'frog': 1,
#   'abolition': 1,
#   'beat': 3,
#   'life': 9,
#   'longest': 1,
#   'motion': 1,
#   'screaming': 1,
#   'eudaemonic': 1,
#   'evil': 3,
#   'three': 5,
#   'biscuit': 1,
#   'vampire': 2,
#   'doors': 1,
#   'why': 1,
#   'basement': 1,
#   'persistence': 1,
#   'impossible': 1,
#   'sting': 1,
#   'scorpion': 1,
#   'rogue': 1,
#   'frost': 1,
#   'philosophic': 1,
#   'whisperer': 1,
#   'battle': 3,
#   'stinky': 1,
#   'crisis': 1,
#   'high': 4,
#   'selected': 1,
#   'textbook': 2,
#   'detective': 1,
#   'glove': 1,
#   'racing': 1,
#   'rain': 3,
#   'rating': 7,
#   'door': 1,
#   'radical': 2,
#   'medici': 1,
#   'fox': 3,
#   'hound': 1,
#   'broke': 1,
#   'egoist': 1,
#   'ussr': 1,
#   'strange': 2,
#   'spoils': 1,
#   'secrets': 2,
#   'grid': 1,
#   'at': 1,
#   'villa': 1,
#   'empty': 1,
#   'stolen': 1,
#   'cat': 2,
#   'spice': 1,
#   'inheritance': 1,
#   'mirrored': 1,
#   'televised': 1,
#   'complex': 1,
#   'military': 1,
#   'teacher': 1,
#   'gray': 1,
#   'coming': 3,
#   'morganville': 1,
#   'eyes': 2,
#   'loneliness': 1,
#   'long': 5,
#   'body': 1,
#   'art': 5,
#   'outlaws': 1,
#   'demolished': 1,
#   'false': 2,
#   'moon': 6,
#   'confidence-man': 1,
#   'bible': 1,
#   'island': 3,
#   'brothers': 1,
#   'authorised': 1,
#   'autobiography': 2,
#   'aquariums': 1,
#   'odd': 1,
#   'paper': 2,
#   'mahatma': 2,
#   'king': 6,
#   'naked': 4,
#   'orchard': 1,
#   'iron': 1,
#   'monks': 1,
#   'council': 1,
#   'citadel': 1,
#   'saga': 39,
#   'italian': 1,
#   'pig': 1,
#   'comics': 1,
#   'mad': 2,
#   'masks': 1,
#   'origins': 2,
#   'principle': 2,
#   'neon': 1,
#   'spoiler': 1,
#   'mathematical': 1,
#   'masters': 1,
#   'amityville': 1,
#   'casualties': 1,
#   'latham': 1,
#   'lost': 5,
#   'oppression': 1,
#   'rats': 2,
#   'overton': 1,
#   'natural': 3,
#   'desert': 3,
#   'killing': 2,
#   'nightmare': 6,
#   'my': 3,
#   'beginning': 4,
#   'phantom': 2,
#   'social': 1,
#   'earth': 5,
#   'terraphiles': 1,
#   'soudan': 1,
#   'box': 1,
#   'mystery': 5,
#   '99': 1,
#   'hindus': 2,
#   'turning': 1,
#   'giants': 1,
#   'descendants': 2,
#   'making': 2,
#   'flash': 2,
#   'sword': 5,
#   'toa': 1,
#   'prestige': 1,
#   'budayeen': 1,
#   'key': 1,
#   'deception': 1,
#   'campaign': 1,
#   'hundred': 1,
#   'poems': 1,
#   'princess': 2,
#   'horrible': 2,
#   'fall': 1,
#   'main-travelled': 1,
#   'a-z': 1,
#   'raven': 1,
#   'buccaneer': 1,
#   'diamond': 1,
#   'loveday': 1,
#   'elegant': 1,
#   'astonishing': 1,
#   'nation': 1,
#   'kingdom': 2,
#   'waves': 2,
#   'hover': 1,
#   'hundred-year': 1,
#   'aroostook': 1,
#   'homo': 1,
#   'crack': 1,
#   'mind': 3,
#   'execution': 1,
#   'half-life': 1,
#   'final': 4,
#   'beggar': 2,
#   'duel': 1,
#   'legend': 8,
#   'boring': 1,
#   'crocus': 1,
#   'tritonian': 1,
#   'mills': 1,
#   'kavanaughs': 1,
#   'theory': 1,
#   'accused': 1,
#   'vanishing': 1,
#   'carry': 1,
#   'woods': 1,
#   'against': 1,
#   'twinkie': 1,
#   'unpleasantness': 1,
#   'bellona': 1,
#   'australian': 1,
#   'thibaults': 1,
#   'raging': 1,
#   'terrible': 1,
#   'hollow': 2,
#   'cia': 2,
#   'cult': 1,
#   'early': 2,
#   'crossing': 1,
#   'knife': 2,
#   'documents': 1,
#   'case': 6,
#   'bok': 1,
#   'definitive': 1,
#   'bone': 1,
#   'journal': 2,
#   'archivist': 1,
#   'compleat': 1,
#   ...},
#  'cita': {'romantica': 1},
#  'romantica': {'playlist': 3},
#  'playlist': {'.': 309,
#   'pre-party': 1,
#   'i': 3,
#   'named': 25,
#   'entitled': 8,
#   'eletro': 1,
#   'the': 5,
#   'titled': 9,
#   'called': 38,
#   'todo': 3,
#   'needs': 16,
#   'and': 3,
#   'forever': 1,
#   'with': 12,
#   'emily': 2,
#   'radar': 1,
#   'all': 2,
#   'lo': 3,
#   'rock': 3,
#   'good': 1,
#   'guest': 6,
#   'latin': 2,
#   'in': 1,
#   '?': 15,
#   'it': 3,
#   'please': 5,
#   'this': 7,
#   'under': 1,
#   'epic': 1,
#   'wild': 2,
#   'a': 6,
#   ',': 6,
#   'electrosafari': 1,
#   'piano': 1,
#   'technical': 2,
#   'trap': 1,
#   'massive': 1,
#   'ironing': 1,
#   'add': 3,
#   'street': 1,
#   'classical': 1,
#   'weekly': 1,
#   'to': 1,
#   'classic': 2,
#   'hits': 1,
#   'metal': 2,
#   'songs': 1,
#   'musica': 1,
#   ':': 3,
#   'chill': 2,
#   'black': 1,
#   'jazzy': 1,
#   'girls': 2,
#   'running': 1,
#   'soul': 2,
#   'journey': 1,
#   'confidence': 1,
#   'reggae': 1,
#   'funk': 1,
#   'soundscapes': 1,
#   'grandes': 1,
#   'women': 1,
#   'virales': 1,
#   'fresh': 1,
#   'los': 1,
#   'pura': 1,
#   'mellowed': 1,
#   'dance': 1,
#   'hype': 1,
#   'korean': 1,
#   'artist': 1,
#   'acoustic': 1,
#   'always': 1,
#   'primavera': 1,
#   'rumba': 1,
#   'domingo': 1,
#   'house': 1,
#   'peaceful': 1,
#   'cool': 1,
#   'picnic': 1,
#   'playlist': 2,
#   'transatlantic': 1,
#   'lazy': 2,
#   'instrumental': 1,
#   'cleaning': 1,
#   'llegando': 1,
#   'canciones': 1,
#   'top': 1,
#   'should': 1,
#   'independent': 1,
#   'fantastic': 1,
#   'heavy': 1,
#   'jennie': 1,
#   'post': 2,
#   'by': 2,
#   'impulso': 1,
#   'melancholia': 1,
#   'kitchen': 1,
#   'cloud': 1,
#   'digster': 1,
#   'entre': 1,
#   'fusion': 1,
#   'bachata': 1,
#   'my': 1,
#   'old': 1,
#   'kickass': 1,
#   'oficial': 1,
#   'for': 1,
#   'tgif': 1,
#   'on': 17,
#   'introspective': 1,
#   'spring': 1,
#   'from': 2,
#   'late': 1,
#   'get': 2,
#   'electronic': 1,
#   'feel': 1,
#   'grime': 1,
#   'funtime': 2,
#   'gypsy': 1,
#   'chilled': 1,
#   'riveting': 1,
#   'urban': 1,
#   'tropical': 1,
#   'estado': 1,
#   'springtime': 1},
#  'clem': {'burke': 2},
#  'burke': {'in': 1, 'to': 2, 'onto': 1},
#  'in': {'my': 78,
#   'indie': 2,
#   'the': 466,
#   'metal': 5,
#   'chill': 1,
#   'pachangueo': 1,
#   'crime': 2,
#   'red': 3,
#   'urban': 1,
#   'puerto': 8,
#   '88': 1,
#   'endorphin': 1,
#   'beth': 1,
#   'concert': 2,
#   'club': 1,
#   '90': 1,
#   'funky': 1,
#   'movies': 3,
#   'residence': 1,
#   'to': 1,
#   'grime': 1,
#   'escapada': 1,
#   'it': 9,
#   'women': 1,
#   'showstopper': 1,
#   'nike': 1,
#   'pre-party': 1,
#   'paradise': 2,
#   'running': 1,
#   'pop': 1,
#   'shuffle': 1,
#   'your': 7,
#   'classic': 1,
#   'all': 3,
#   'lela': 1,
#   'blue': 4,
#   'jaime': 1,
#   'acoustic': 1,
#   'sweet': 1,
#   'kaitlin': 1,
#   'paris': 4,
#   'workout': 1,
#   'playlist': 3,
#   'detroit': 3,
#   'guitar': 1,
#   'a': 43,
#   'reggae': 1,
#   'heaven': 3,
#   'dallas': 2,
#   'punk': 1,
#   'nu': 1,
#   'their': 3,
#   'person': 1,
#   'stress': 1,
#   'halloween': 1,
#   '2': 9,
#   'mellowed': 1,
#   'in': 6,
#   'for': 2,
#   'japan': 1,
#   'mondovi': 1,
#   'coalton': 1,
#   'oh': 7,
#   'madison': 1,
#   '1': 48,
#   'bonaire': 4,
#   '345': 1,
#   'spaghetti': 1,
#   'emmons': 1,
#   'sandstone': 1,
#   'sugarville': 1,
#   'twenty': 11,
#   'strandburg': 1,
#   'grainola': 1,
#   'niger': 5,
#   'ok': 5,
#   'papua': 2,
#   'timberville': 1,
#   'town': 11,
#   'two': 7,
#   'topton': 1,
#   'heard': 2,
#   'bonita': 1,
#   'gwynedd': 2,
#   'one': 48,
#   'tracyton': 1,
#   'iran': 2,
#   'allison': 1,
#   'mauritania': 1,
#   'de': 5,
#   'chile': 3,
#   'nh': 7,
#   'mp': 3,
#   'blankets': 1,
#   'jacksboro': 1,
#   'guernsey': 3,
#   'serbia': 8,
#   'brazil': 8,
#   'friday': 1,
#   'pw': 6,
#   'alderwood': 1,
#   'mt': 5,
#   'belhaven': 1,
#   'germania': 1,
#   'apache': 1,
#   'mcmurray': 1,
#   'alabama': 2,
#   'cazenovia': 1,
#   'moody': 1,
#   'ms': 6,
#   'jagual': 1,
#   'bradford': 1,
#   'comunas': 1,
#   'lebanon': 2,
#   'brunei': 4,
#   'colombia': 3,
#   'western': 3,
#   'south': 29,
#   'follett': 1,
#   'uzbekistan': 5,
#   'montana': 5,
#   'california': 6,
#   'georgia': 7,
#   'new': 43,
#   'salado': 1,
#   'midday': 1,
#   'meers': 1,
#   'kenova': 1,
#   'vanlue': 1,
#   'tokelau': 3,
#   'dominica': 2,
#   'deersville': 2,
#   'wa': 1,
#   'comoros': 1,
#   'luxor': 1,
#   'neighboring': 10,
#   'moravian': 1,
#   'norfolk': 3,
#   'curacao': 2,
#   'nevada': 3,
#   'rose': 2,
#   'needmore': 1,
#   'robert': 2,
#   'rainbow': 3,
#   'missouri': 3,
#   'north': 28,
#   'sc': 6,
#   'wy': 3,
#   'montenegro': 3,
#   'verona': 1,
#   'gober': 1,
#   'slick': 2,
#   'northway': 1,
#   'milladore': 1,
#   'mi': 5,
#   'nv': 5,
#   'oklahoma': 4,
#   'algeria': 2,
#   'samoa': 2,
#   'gurabo': 1,
#   'cimarron': 1,
#   'johnson': 1,
#   'portugal': 4,
#   'bulgaria': 1,
#   'ledoux': 1,
#   'malin': 1,
#   'madagascar': 2,
#   'supper': 1,
#   'kit': 1,
#   'kellerton': 1,
#   'tx': 1,
#   'md': 8,
#   'walpole': 1,
#   'gabon': 6,
#   'pelican': 1,
#   'poncha': 1,
#   'american': 7,
#   'germfask': 1,
#   'hungary': 1,
#   'maine': 5,
#   'exmore': 1,
#   'mayotte': 3,
#   'distant': 2,
#   'connecticut': 5,
#   'ri': 5,
#   'liberia': 2,
#   'florida': 3,
#   'fort': 8,
#   'hallam': 1,
#   'vi': 3,
#   'lavina': 2,
#   'conehatta': 1,
#   'cohocton': 1,
#   'pa': 6,
#   'fm': 8,
#   'illinois': 5,
#   'nj': 6,
#   'henniker': 1,
#   'birch': 2,
#   'hurricane': 1,
#   'wisconsin': 7,
#   'bone': 1,
#   'mclaurin': 1,
#   'jenkins': 1,
#   'maldives': 1,
#   'pataskala': 1,
#   'nc': 4,
#   'wallsburg': 1,
#   'moon': 1,
#   'kellnersville': 1,
#   'west': 20,
#   'china': 7,
#   'calistoga': 1,
#   'russia': 3,
#   'tuvalu': 4,
#   'plandome': 1,
#   'indiana': 5,
#   'carpenterville': 1,
#   'gasport': 1,
#   'ma': 6,
#   'arkansas': 7,
#   'east': 13,
#   'cross': 2,
#   'gilluly': 1,
#   'irma': 2,
#   'chowchilla': 1,
#   'ak': 5,
#   'freshwater': 1,
#   'alaska': 4,
#   'liechtenstein': 4,
#   'hilt': 1,
#   '19': 4,
#   'estonia': 3,
#   'bowling': 1,
#   'slovakia': 3,
#   'pollock': 1,
#   'watauga': 1,
#   'char': 1,
#   'arizona': 4,
#   'michigan': 4,
#   'village': 1,
#   'northern': 6,
#   'eleven': 4,
#   'nd': 4,
#   'kuwait': 7,
#   'arkport': 1,
#   'moldova': 2,
#   'hawaii': 2,
#   'loyola': 2,
#   'tn': 4,
#   'somalia': 3,
#   'olton': 1,
#   'ky': 4,
#   'colorado': 9,
#   'lafe': 1,
#   'shingleton': 1,
#   'utah': 2,
#   '5': 6,
#   'osage': 1,
#   'holiday': 2,
#   'alberton': 1,
#   'law': 8,
#   'cottondale': 1,
#   'wheeler': 1,
#   'pinecliffe': 1,
#   'eminence': 1,
#   'federated': 4,
#   'olive': 1,
#   'eastern': 1,
#   'macedonia': 2,
#   'exira': 1,
#   'eleele': 1,
#   'greensburg': 2,
#   'indiahoma': 1,
#   'eight': 5,
#   'albania': 5,
#   'or': 4,
#   'orchard': 1,
#   'gu': 6,
#   'blodgett': 1,
#   'meadow': 1,
#   'glazier': 1,
#   'pagosa': 1,
#   'lavalette': 1,
#   'qatar': 3,
#   'ashmore': 1,
#   'andorra': 4,
#   'woodston': 1,
#   'al': 8,
#   '16': 3,
#   'grand': 5,
#   'goodland': 1,
#   'clinchco': 1,
#   'brokaw': 1,
#   'irvine': 1,
#   '56': 1,
#   'soldier': 1,
#   'gasconade': 1,
#   'dc': 6,
#   'jamaica': 1,
#   '18': 1,
#   'niagara': 2,
#   'myanmar': 3,
#   'il': 7,
#   'ward': 1,
#   '8': 10,
#   'lorain': 1,
#   'hagaman': 1,
#   'beauregard': 1,
#   'guanica': 1,
#   'belle': 1,
#   'lesotho': 2,
#   'federal': 1,
#   'aruba': 3,
#   'bangladesh': 1,
#   'minnesota': 8,
#   '22': 2,
#   'yamhill': 1,
#   'antarctica': 2,
#   'tonga': 1,
#   'brockway': 1,
#   'sealy': 1,
#   'trinidad': 3,
#   'creola': 1,
#   'mississippi': 3,
#   '11': 6,
#   'carnot': 2,
#   'jemez': 1,
#   'keeling': 1,
#   'oneonta': 1,
#   'denmark': 3,
#   'almyra': 1,
#   '10': 3,
#   'modesto': 1,
#   'saint': 20,
#   'svalbard': 2,
#   'cochran': 1,
#   'ambler': 1,
#   'juniper': 1,
#   'clermont': 1,
#   'edgemoor': 1,
#   '42': 2,
#   'wagram': 1,
#   'everson': 1,
#   'grenada': 2,
#   'ireland': 3,
#   'gleed': 1,
#   'bloom': 1,
#   'netherlands': 3,
#   'australia': 4,
#   'fullerville': 1,
#   'wrigley': 1,
#   'kyrgyzstan': 3,
#   'as': 6,
#   'union': 2,
#   'hallowell': 1,
#   '15': 4,
#   'mccoll': 1,
#   'tennessee': 5,
#   'uncas': 1,
#   'iowa': 6,
#   'tunisia': 3,
#   'shamrock': 1,
#   'plain': 1,
#   'durant': 1,
#   'port': 5,
#   'ten': 4,
#   'indonesia': 3,
#   'garner': 1,
#   'greece': 3,
#   'pr': 3,
#   'veyo': 1,
#   'montserrat': 4,
#   'hayden': 1,
#   'northcote': 1,
#   'ravensdale': 1,
#   'mountain': 2,
#   'delaware': 5,
#   'coronado': 1,
#   'cedarburg': 1,
#   'kansas': 3,
#   'fairview': 2,
#   'idaho': 3,
#   'crocker': 1,
#   'takilma': 1,
#   'me': 5,
#   'gate': 1,
#   'equatorial': 2,
#   'newtown': 1,
#   'palau': 8,
#   'six': 12,
#   'san': 12,
#   'sierraville': 1,
#   'haiti': 2,
#   'winnie': 1,
#   'lazy': 1,
#   'la': 10,
#   'cotton': 1,
#   'laneville': 1,
#   'glennie': 1,
#   'elberta': 1,
#   'roach': 1,
#   'snow': 1,
#   'turkmenistan': 1,
#   'ga': 7,
#   'ansonia': 1,
#   'mount': 7,
#   '10:24': 1,
#   'washington': 7,
#   'riverview': 1,
#   'rwanda': 1,
#   'ucolo': 1,
#   'finland': 2,
#   'timbo': 2,
#   'statham': 1,
#   'niue': 1,
#   'seven': 11,
#   'douglas': 1,
#   'luray': 1,
#   'bolivia': 3,
#   'democratic': 1,
#   'hong': 4,
#   'datil': 2,
#   'vanuatu': 4,
#   'nicholasville': 1,
#   'riddlesburg': 1,
#   'mulvane': 1,
#   'pidcoke': 1,
#   'hutchings': 1,
#   'macao': 3,
#   '13': 4,
#   'haskell': 1,
#   '37': 1,
#   'saudi': 4,
#   'germany': 2,
#   'suriname': 1,
#   'mauritius': 1,
#   'thirty': 1,
#   'graniteville': 1,
#   'id': 5,
#   'wi': 3,
#   'upper': 1,
#   'punjabi': 1,
#   'latvia': 2,
#   'stonewood': 2,
#   'bermuda': 2,
#   'pilot': 1,
#   'vermont': 7,
#   'fiji': 2,
#   'burundi': 2,
#   'malaysia': 3,
#   'kenya': 2,
#   '12': 4,
#   'pohick': 1,
#   'allentown': 1,
#   'bruno': 1,
#   'clawson': 1,
#   'home': 1,
#   'snapfinger': 1,
#   'half': 1,
#   'anderson': 2,
#   'central': 4,
#   'seychelles': 1,
#   'wabuska': 1,
#   'rocky': 3,
#   'venezuela': 3,
#   'glenarden': 1,
#   'lithuania': 1,
#   'gibraltar': 1,
#   'callicoon': 1,
#   'newton': 1,
#   'eucalyptus': 1,
#   'diwali': 1,
#   'beech': 1,
#   'salina': 1,
#   'putnam': 1,
#   'senegal': 2,
#   'sd': 6,
#   'robinette': 1,
#   'being': 1,
#   'sunnybrook': 1,
#   'searsport': 1,
#   'jersey': 4,
#   'manadonese': 1,
#   'shambaugh': 1,
#   'iraq': 1,
#   'fork': 1,
#   'district': 3,
#   'atlas': 3,
#   'kentucky': 10,
#   'ar': 8,
#   'sint': 3,
#   'bynum': 1,
#   'exell': 1,
#   'lodi': 1,
#   'el': 7,
#   'culver': 1,
#   'botswana': 4,
#   'pizzeria': 1,
#   'burkina': 4,
#   'ocean': 4,
#   'donnelly': 1,
#   'antietam': 1,
#   'wylliesburg': 1,
#   'tuolumne': 1,
#   'sterling': 1,
#   'satanta': 2,
#   'long': 3,
#   'honduras': 3,
#   'hollenberg': 1,
#   'nine': 8,
#   'brookneal': 1,
#   'malta': 2,
#   'vt': 3,
#   'hord': 1,
#   'egypt': 4,
#   'seeley': 1,
#   'maryland': 3,
#   'brucetown': 1,
#   'ashland': 1,
#   'argentina': 2,
#   'hallwood': 2,
#   'naytahwaush': 1,
#   'hainesville': 1,
#   'medford': 1,
#   'lake': 5,
#   'valley': 2,
#   'belgium': 3,
#   'cuba': 3,
#   'falkland': 2,
#   'decaturville': 1,
#   'mango': 1,
#   'u.s.': 2,
#   'ut': 6,
#   'lucerne': 1,
#   'malawi': 1,
#   'johnston': 1,
#   'romania': 3,
#   'ukraine': 2,
#   'bosnia': 3,
#   'maple': 1,
#   'pershing': 1,
#   'nebraska': 5,
#   'rockport': 1,
#   'booker': 1,
#   'ethiopia': 1,
#   'that': 1,
#   '9': 4,
#   'palco': 1,
#   'pitcairn': 1,
#   'four': 2,
#   'london': 1,
#   'ivory': 1,
#   'jansen': 1,
#   'ne': 9,
#   'bushkill': 1,
#   'tillicum': 1,
#   'burkettsville': 1,
#   'brusly': 1,
#   'delanson': 1,
#   'urbanette': 1,
#   'whitewater': 1,
#   'keller': 1,
#   'togo': 2,
#   'elk': 1,
#   'unalaska': 1,
#   'ludlow': 1,
#   'adelaide': 1,
#   'cuney': 1,
#   'co-operative': 1,
#   'mn': 4,
#   'three': 6,
#   'french': 7,
#   'swaziland': 1,
#   'baker': 1,
#   'oman': 1,
#   'iron': 2,
#   'foley': 1,
#   'viroqua': 1,
#   'sturgeon': 1,
#   'zambia': 4,
#   'fayette': 1,
#   'sao': 1,
#   'hecker': 1,
#   'grandview': 1,
#   'singapore': 4,
#   '6': 1,
#   'pioneer': 1,
#   'turkey': 2,
#   'cammack': 1,
#   'armenia': 3,
#   'ia': 5,
#   'city': 2,
#   'old': 4,
#   'guadeloupe': 3,
#   'eagle': 1,
#   'independence': 1,
#   'green': 2,
#   'bouchon': 1,
#   'taiwan': 5,
#   'hi': 3,
#   'bonaparte': 1,
#   'yakima': 1,
#   'leopold': 1,
#   'co': 2,
#   'oakes': 1,
#   'croatia': 4,
#   'top': 1,
#   'france': 4,
#   'mongolia': 2,
#   'ca': 3,
#   'lewisville': 1,
#   'louisiana': 6,
#   'waddy': 1,
#   'owings': 1,
#   'ettrick': 1,
#   'apr.': 1,
#   'rhode': 3,
#   'delhi': 1,
#   'hills': 1,
#   'brookwood': 1,
#   'az': 5,
#   'hypoluxo': 1,
#   'virginia': 4,
#   'harding': 1,
#   'sparks': 1,
#   'crouch': 2,
#   'within': 2,
#   'canal': 1,
#   'white': 4,
#   'karnataka': 1,
#   'fl': 4,
#   'tennyson': 1,
#   'dodge': 1,
#   'kazakhstan': 2,
#   'rocksprings': 1,
#   'bouvet': 2,
#   'rixford': 1,
#   'micronesia': 2,
#   'yeager': 1,
#   'pinto': 1,
#   'geddes': 1,
#   'friona': 1,
#   'twelve': 3,
#   'deweese': 2,
#   'piper': 1,
#   'lauderdale': 1,
#   'falmouth': 1,
#   'lumpkin': 1,
#   'enid': 1,
#   'montverde': 1,
#   'marshall': 2,
#   'cyprus': 2,
#   'pelland': 1,
#   'ewen': 1,
#   'hitchita': 1,
#   'muscle': 1,
#   'conshohocken': 1,
#   'fleetwood': 1,
#   'southern': 1,
#   'faraway': 2,
#   'monaco': 2,
#   'texas': 6,
#   'shabbona': 1,
#   'cambodia': 2,
#   'pakistan': 1,
#   'cook': 1,
#   'nisswa': 1,
#   'tajikistan': 3,
#   'roads': 1,
#   'culdesac': 1,
#   'roseville': 1,
#   'bastian': 1,
#   'climax': 1,
#   'barbados': 3,
#   'frisco': 1,
#   'childersburg': 1,
#   'ct': 8,
#   'luquillo': 1,
#   'hackney': 1,
#   'ludden': 1,
#   'palestine': 2,
#   'raytown': 1,
#   'wv': 3,
#   'raleigh': 1,
#   'ny': 5,
#   'skaneateles': 1,
#   'henlopen': 1,
#   'armour': 1,
#   'horatio': 1,
#   'paraguay': 3,
#   'otho': 1,
#   'branford': 1,
#   'irvington': 1,
#   'panama': 1,
#   'dutch': 1,
#   'enfield': 1,
#   'jordan': 2,
#   'cawker': 1,
#   'united': 2,
#   'arp': 1,
#   'seabrook': 1,
#   'peru': 2,
#   'mineola': 1,
#   'argusville': 1,
#   'santa': 1,
#   'skillman': 1,
#   'darnell': 1,
#   'anguilla': 2,
#   'israel': 1,
#   'crugers': 1,
#   'adrian': 1,
#   'manning': 1,
#   'graf': 1,
#   'wadsworth': 1,
#   'milton-freewater': 1,
#   'ottoville': 1,
#   'guyana': 1,
#   'feb': 1,
#   'le': 2,
#   'hurffville': 1,
#   'poland': 2,
#   'ware': 1,
#   'owenyo': 1,
#   'state': 1,
#   'massachusetts': 3,
# ...
#  'troy': {'to': 1, 'andrews': 1, 'van': 1},
#  'background': {'playlist': 2, 'to': 1},
#  'hatfield': {'and': 1},
#  'north': {'to': 2,
#   'carolina': 12,
#   'dakota': 17,
#   'amityville': 2,
#   'korea': 4,
#   'indian': 3,
#   'st': 1,
#   'lima': 1,
#   'river': 1,
#   'salt': 2,
#   'creek': 1,
#   'brunswick': 1,
#   'sioux': 1,
#   'gulfport': 1,
#   'epworth': 1,
#   'bonneville': 1,
#   'wolcott': 1,
#   'american': 13,
#   'star': 1},
#  'tour': {'generacion': 1, '2009': 1, 'compilation': 1, '2013': 1},
#  'generacion': {'rbd': 1},
#  'rbd': {'en': 1},
#  'vivo': {'to': 1},
#  'roadrunner': {'rec': 3},
#  'rec': {'new': 3},
#  'releases': {'playlist': 2, 'list': 1, 'spotify': 3},
#  'have': {'marit': 1,
#   'known': 1,
#   'a': 17,
#   'plaid': 1,
#   'pat': 1,
#   'you': 1,
#   'this': 1,
#   'southeastern': 1,
#   'six': 1,
#   'four': 2,
#   'two': 1,
#   'eight': 1,
#   'the': 7,
#   'will': 1,
#   'lunch': 1,
#   'something': 1,
#   'another': 1,
#   'no': 1,
#   'zvooq': 1,
#   'music': 1,
#   'to': 1,
#   'an': 1,
#   'eyes': 1,
#   'spent': 1,
#   'animated': 1,
#   'movie': 1,
#   'movies': 1,
#   'fun': 1,
#   'sword': 1},
#  'marit': {'bergman': 1},
#  'bergman': {'added': 1},
#  'block': {'brochure': 1, 'building': 2, 'movement': 1},
#  'brochure': {'welcome': 1},
#  'welcome': {'to': 7},
#  'soil': {'6': 1},
#  '6': {'onto': 1,
#   'in': 11,
#   'at': 20,
#   'people': 13,
#   'pm': 4,
#   'close': 1,
#   ',': 6,
#   'to': 32,
#   'that': 3,
#   'pm.': 1,
#   'years': 3,
#   'on': 2,
#   'members': 1,
#   'am': 6,
#   'points': 243,
#   '.': 88,
#   'stars': 235,
#   'for': 6,
#   'rating': 17,
#   'possiable': 1,
#   'and': 7,
#   'possible': 4,
#   '?': 1,
#   'give': 2,
#   'is': 2,
#   'but': 2,
#   'read': 1,
#   'star': 3,
#   '!': 1,
#   'a': 1,
#   'score': 1,
#   'point': 1,
#   'ratings': 1,
#   'rate': 1,
#   'goes': 1,
#   'series': 1,
#   'total': 2,
#   'the': 1,
#   'are': 1,
#   'i': 1,
#   'out': 1,
#   'p.m.': 1},
#  'wright': {'album': 1, "'s": 1, 'and': 1, 'from': 1, 'on': 1, '?': 1},
#  'collective': {'playlist': 2, 'for': 1, 'please': 1},
#  'marilyn': {'manson': 1, 'moore': 1, 'playing': 1},
#  'manson': {'tune': 1},
#  'dickey': {'betts': 1},
#  'betts': {'to': 1},
#  'thursday': {'playlist': 4, 'for': 1, 'forecast': 1, 'night': 1, ',': 1},
#  'cham': {'to': 1},
#  'cloud': {'rap': 4,
#   'indicate': 1,
#   'action': 1,
#   'coverage': 3,
#   'here': 1,
#   'in': 5,
#   'next': 1,
#   'activity': 1,
#   'forcast': 1,
#   'forecast': 1,
#   'cover': 1,
#   'one': 1,
#   '-': 2,
#   '?': 1},
#  'rap': {'playlist': 2, '.': 1, 'on': 1, 'album': 1, 'over': 1},
#  'atticus': {'ross': 2},
#  'lindsey': {'cardinale': 1},
#  'cardinale': {'into': 1},
#  'hillary': {'clinton': 4, ',': 1},
#  'clinton': {"'s": 4, 'street': 4, ',': 1},
#  'history': {'month': 4,
#   'salute': 1,
#   ':': 1,
#   'two': 1,
#   'decoded': 1,
#   'of': 15,
#   'by': 1,
#   '3': 1,
#   ',': 1,
#   'and': 1,
#   'review': 2,
#   'picture': 1,
#   'society': 1,
#   'repeating': 1,
#   'from': 1,
#   '?': 1},
#  'month': {'playlist': 4,
#   'in': 11,
#   '.': 3,
#   'for': 2,
#   'at': 1,
#   'from': 3,
#   'will': 1,
#   '?': 1},
#  'gate': {'through': 1, 'city': 1, 'for': 1, 'is': 1, 'of': 2, 'ii': 1},
#  'through': {'bloodstained': 1,
#   'the': 9,
#   'life': 1,
#   'walls': 1,
#   'distant': 1,
#   'slaughter': 1,
#   'oblivion': 1,
#   'thick': 1},
#  'bloodstained': {'mirrors': 1},
#  'mirrors': {'to': 1},
#  'feelin': {"'": 2},
#  'ferrer': {'into': 1},
#  'edna': {'st': 2, 'and': 2},
#  'vincent': {'millay': 2, 'and': 8, 'paul': 1, '.': 1},
#  'millay': {'playlist': 1},
#  'madman': {'to': 1},
#  'trap': {'land': 5, '5': 1, 'iv': 1},
#  'land': {'playlist': 3,
#   'of': 2,
#   'three': 1,
#   'zero': 1,
#   'touch': 1,
#   'in': 1,
#   '?': 1,
#   'playing': 1,
#   'time': 1},
#  'chas': {'chandler': 1},
#  'chandler': {'to': 1},
#  'aux': {'cord': 2},
#  'cord': {'privileges': 2},
#  'kan': {'mikami': 2, 'on': 1, 'man': 1},
#  'mikami': {'on': 1, 'tune': 1},
#  'let': {'the': 1, 'me': 28, "'s": 3},
#  'season': {'in': 2,
#   'three': 1,
#   'deserves': 1,
#   'is': 1,
#   'of': 2,
#   '3': 1,
#   'playing': 1},
#  'lo-fi': {'love': 3},
#  'any': {'andrew': 1,
#   'restaurant': 5,
#   'kind': 1,
#   'popular': 1,
#   'pub': 1,
#   'snowfall': 3,
#   'rainfall': 1,
#   'hail': 1,
#   'hotter': 1,
#   'cloud': 2,
#   'predicted': 1,
#   'fog': 1,
#   'music': 1,
#   'song': 4,
#   'chanson': 1,
#   'album': 1,
#   'chant': 2,
#   'sixties': 1,
#   'top': 1,
#   'tune': 1,
#   'nineties': 1,
#   'track': 1,
#   'painting': 1,
#   'creative': 1,
#   'mountain': 2,
#   'movies': 2,
#   'animated': 8,
#   'theater': 1,
#   'type': 1,
#   'films': 4,
#   'movie': 2,
#   'nearby': 1},
#  'andrew': {'hurley': 1,
#   'hewitt': 1,
#   'findon': 1,
#   'cash': 1,
#   'diamond': 1,
#   'lloyd': 2,
#   '.': 1},
#  'hurley': {'album': 2, 'mountain': 1},
#  'timeless': {'love': 4},
#  'yourself': {'tonight': 1, 'with': 1, 'in': 1},
#  'tonight': {'to': 1,
#   '.': 2,
#   'for': 1,
#   'at': 3,
#   'far': 1,
#   '?': 1,
#   'only': 1,
#   'online': 1},
#  'las': {'canciones': 2,
#   'estrellas': 3,
#   'lomas': 1,
#   'batuecas': 1,
#   'aventuras': 1},
#  'canciones': {'mas': 2, 'del': 2, 'que': 2},
#  'mas': {'lindas': 2, 'playlist': 1, 'dance': 2, 'que': 1},
#  'lindas': {'del': 2},
#  'del': {'mundo': 2,
#   'hip': 4,
#   'recuerdo': 2,
#   'tha': 1,
#   'rock': 2,
#   'jarama': 1,
#   'dia': 1,
#   'cielo': 1,
#   'rosario': 1},
#  'mundo': {'playlist': 1},
#  'roy': {'orbison': 2, 'to': 1, 'lake': 1, 'colt': 1},
#  'orbison': {'song': 1, 'tunes': 1},
#  'bum': {'note': 1},
#  'note': {'and': 1, 'show': 1},
#  'bead': {'of': 1},
#  'sweat': {'to': 1, 'and': 1},
#  'relief': {'playlist': 3},
#  'sara': {'hickman': 1, 'carter': 1},
#  'hickman': {'to': 1},
#  'targeted': {'list': 1, 'in': 1, 'playlist': 1},
#  'jonathan': {'arons': 1, 'davis': 1, 'livingston': 1},
#  'arons': {'to': 1},
#  'electronics': {'playlist': 2},
#  'mary': {'wells': 1,
#   'jane': 4,
#   'fahl': 1,
#   'at': 1,
#   'in': 1,
#   'macgregor': 1,
#   ':': 1,
#   'van': 1,
#   'lou': 2,
#   'kom': 1},
#  'wells': {'sings': 1, 'in': 1},
#  'sings': {'my': 1, 'spanish': 1, 'rodgers': 1, 'steve': 1, 'the': 1},
#  'guy': {'to': 2, 'is': 1, 'warren': 1, 'sebastian': 1},
#  'electro': {'sur': 4, 'workout': 1, 'latino': 2},
#  'sur': {'playlist': 3, 'have': 1},
#  'soft': {'rock': 2, 'pop': 2, 'parade': 1},
#  'd-day': {'dodgers': 1},
#  'dodgers': {'to': 1},
#  'running': {'power': 2,
#   'tempo': 1,
#   'to': 3,
#   'playlist': 1,
#   '.': 1,
#   'series': 1,
#   'in': 1},
#  'john': {'schlitt': 1,
#   'tesh': 2,
#   'winston': 2,
#   'brown': 1,
#   'williams': 3,
#   'deacon': 1,
#   'william': 1,
#   'scofield': 1,
#   'pearson': 2,
#   'ross': 1,
#   'n': 1,
#   'maher': 1,
#   'bundrick': 1,
#   'doyle': 1,
#   'clayton': 1,
#   'oates': 1,
#   'bonham': 1,
#   'mccrea': 1,
#   'doe': 1,
#   'feinstein': 1,
#   'farnham': 1,
#   'lomax': 1,
#   '4': 1,
#   ',': 1,
#   'michael': 1,
#   'list': 1,
#   'coltrane': 1,
#   'is': 1},
#  'schlitt': {'in': 1},
#  'bajo': {'las': 3},
#  'estrellas': {'playlist': 2},
#  'vikku': {'vinayakram': 1},
#  'vinayakram': {'to': 1},
#  'samba': {'to': 1, 'beat': 1},
#  'jukebox': {'boogie': 1},
#  'boogie': {'rhythm': 1},
#  'rhythm': {'&': 1, 'and': 4, 'to': 2, 'playlist': 2},
#  'brad': {'kane': 1, 'paisley': 1},
#  'kane': {'to': 1, 'or': 1},
#  'pumping': {'iron': 2},
#  'iron': {'soundtrack': 1,
#   'playlist': 1,
#   '.': 1,
#   'springs': 1,
#   'gates': 1,
#   'mountain': 1,
#   'mills': 1,
#   'fist': 1,
#   'television': 1,
#   'seed': 1},
#  'soundtrack': {'.': 5,
#   '007': 1,
#   '2': 1,
#   '?': 1,
#   'from': 16,
#   'by': 14,
#   'on': 8,
#   'tunes': 1,
#   'that': 1,
#   'titled': 3,
#   'called': 17,
#   'for': 12,
#   'tianjin': 1,
#   'and': 1,
#   'to': 1,
#   'bridge': 1,
#   'adobe': 1,
#   'the': 2,
#   'ready': 1,
#   'iheartradio': 1,
#   'pitch': 1,
#   'of': 2,
#   'download': 1,
#   'african': 1,
#   'in': 1,
#   'bed': 1},
#  'indiespain': {'list': 1},
#  'od': {'mene': 1, '6': 1},
#  'mene': {'se': 1},
#  'se': {'odvikavaj': 1, 'eu': 1},
#  'odvikavaj': {'to': 1},
#  'favorite': {'slaughterhouse': 3,
#   'coffeehouse': 2,
#   'artist': 2,
#   'track': 1,
#   'fantasy': 1},
#  'slaughterhouse': {'playlist': 2},
#  'lullaby': {'of': 2, 'list': 1, 'on': 1, ':': 1},
#  'birdland': {'onto': 1},
#  'fest': {'.': 1, 'playlist': 2},
#  'sarah': {'blasko': 1,
#   'vaughan': 1,
#   'geronimo': 2,
#   'harding': 1,
#   'brightman': 1,
#   'connor': 1,
#   'the': 1},
#  'blasko': {'onto': 1},
#  'metalsucks': {'playlist': 4},
#  'korean': {'osts': 5},
#  'osts': {'playlist': 2, '.': 1},
#  'cream': {'to': 2, 'cake': 2, 'at': 1},
#  'take': {'me': 8,
#   'pictures': 1,
#   'it': 1,
#   'up': 1,
#   'my': 3,
#   'three': 2,
#   'a': 1,
#   'nine': 1,
#   'elsa': 1,
#   'four': 1,
#   'reservations': 1,
#   'christy': 1,
#   'care': 2,
#   'you': 1,
#   'that': 1,
#   'another': 1,
#   'this': 1},
#  'dear': {'old': 2, 'hearts': 1, 'by': 1},
#  'blighty': {'to': 1},
#  'dark': {'indie': 3,
#   'dance': 1,
#   'days': 1,
#   'abode': 1,
#   'tea-time': 1,
#   '3': 1,
#   ':': 1,
#   '.': 1,
#   'side': 1,
#   'stranger': 1,
#   'world': 1},
#  'gisela': {'song': 1},
#  'dancehall': {'official': 3},
#  'histoire': {'de': 1},
#  'melody': {'nelson': 1,
#   'to': 1,
#   'and': 2,
#   'music': 3,
#   'starting': 1,
#   'from': 13,
#   'by': 11,
#   '.': 2,
#   'on': 2,
#   'of': 1,
#   'gardot': 1},
#  'nelson': {'to': 2, 'style': 1, 'delisle': 2, 'live': 1},
#  'funtime': {'.': 1, 'activity': 6, 'playlist': 1},
#  'punk': {'espanol': 3,
#   'rock': 7,
#   'essentials': 4,
#   "'s": 1,
#   'powerhouses': 2,
#   'playlist': 6,
#   'never': 1,
#   'by': 1,
#   'perfection': 1,
#   '.': 2,
#   'music': 2,
#   'genre': 1},
#  'mood': {'to': 2},
#  'folksy': {'love': 2},
#  'jerry': {'dixon': 2, 'lee': 1, 'garcia': 1, 'showing': 1},
#  'dixon': {'song': 1, 'to': 1, 'on': 1, 'a': 1},
#  'tokyo': {'rising': 4, 'for': 1},
#  'grim': {'skunk': 1},
#  'skunk': {'to': 1},
#  'jennie': {',': 2, 'to': 1, 'brice': 1},
#  'dias': {'felices': 1, 'de': 2},
#  'felices': {'to': 1},
#  'reggaeton': {'playlist': 3, 'classics': 1, '2017': 1},
#  'candlelight': {'to': 1},
#  'afterwork': {'playlist': 3, 'to': 1, 'this': 1},
#  'placers': {'to': 1},
#  'mayya': {'to': 1},
#  'manhattan': {'con': 2, 'at': 2, 'project': 1, 'a': 1},
#  'amor': {'playlist': 4, 'amor': 2, 'to': 1, 'puro': 1, ':': 1},
#  'nastya': {'kamenskih': 3},
#  'kamenskih': {'song': 1, 'on': 1},
#  'robin': {'s': 1, 'hood': 4, 'trower': 3, "'s": 1, 'need': 1, 'redbreast': 1},
#  's': {'to': 1, 'anderson': 1, 'snowstorm': 1},
#  'signed': {'xoxo': 3},
#  'xoxo': {'playlist': 3},
#  'olympia': {'1959': 1, '81': 1, '1974': 1},
#  '1959': {'to': 1, 'on': 1, '.': 1, 'songs': 1, 'by': 2},
#  'delta': {'to': 1, 'junction': 1},
#  'enamorandose': {'playlist': 2},
#  'rocksteady': {'playlist': 1},
#  'funtwo': {'to': 1},
#  'fever': {'track': 1,
#   'playlist': 5,
#   'list': 1,
#   '2': 1,
#   'saga': 1,
#   ':': 1,
#   'playing': 1},
#  'siesta': {'playlist': 1},
#  'kevin': {'cadogan': 2, 'ridel': 1, 'johansen': 2, 'fowler': 1, 'jonas': 1},
#  'cadogan': {'to': 1},
#  'spooning': {'playlist': 1},
#  'alan': {'wilson': 1, 'jardine': 1, 'released': 1},
#  'wilson': {'track': 1, 'av': 2, 'and': 1, 'album': 1},
#  'luis': {'fonsi': 6, 'alfonzo': 1, 'rey': 1},
#  'fonsi': {'playlist': 5},
#  'wild': {'country': 6,
#   '&': 4,
#   'and': 2,
#   'river': 1,
#   'frontier': 1,
#   'streetdanz': 1,
#   'boy': 1,
#   'blood': 1,
#   'geese': 1,
#   'boys': 1,
#   'cats': 1,
#   'about': 1,
#   'side': 1,
#   'things': 1,
#   'solutions': 1,
#   'is': 1,
#   'at': 1,
#   'america': 1,
#   'on': 1,
#   'jumbo': 1},
#  'great': {'day': 1,
#   'female': 1,
#   'grape': 1,
#   'house': 2,
#   'grandfather': 5,
#   'bay': 1,
#   'science': 1,
#   'classics': 1,
#   'managing': 1,
#   'hydration': 1,
#   'adventures': 1,
#   'lakes': 1,
#   'irish': 1,
#   'legacy': 1,
#   'townes': 1,
#   'apes': 1,
#   'escape': 10,
#   'balls': 1,
#   'question': 1,
#   'guy': 1,
#   'air': 1},
#  'ricky': {'nelson': 1, 'martin': 1, 'wilson': 1, 'bell': 2, 'skaggs': 1},
#  'x': {'playist': 1,
#   'forza': 1,
#   'amore': 1,
#   'red': 1,
#   'list': 1,
#   'playlist': 1,
#   'window': 1},
#  'ronnie': {'james': 1, 'wood': 1},
#  'dio': {'tune': 1, 'years': 1},
#  'isabella': {"'s": 1, 'and': 1},
#  'pat': {'smear': 1,
#   'monahan': 1,
#   'alger': 1,
#   'kirtley': 1,
#   'and': 1,
#   'garrett': 1},
#  'smear': {'on': 1},
#  'thomas': {'rhett': 2, 'a': 1, 'anders': 1, 'hynes': 4, 'jefferson': 1},
#  'rhett': {'playlist': 1},
#  'hate': {'myself': 1, 'masquerade': 1, 'music': 1},
#  'myself': {'and': 2},
#  'die': {'to': 1,
#   'down': 1,
#   'deserves': 1,
#   'chronicle': 1,
#   'in': 1,
#   'one': 1,
#   '-': 1,
#   '?': 1},
#  'string': {'peacefulness': 2, 'quartet': 2, 'theory': 2, 'video': 1},
#  'cena': {'elegante': 4, 'con': 1},
#  'elegante': {'playlist': 4},
#  'jency': {'anthony': 1},
#  'jtr': {'on': 1},
#  'get': {'going': 2,
#   'what': 2,
#   'your': 2,
#   'added': 5,
#   'happy': 1,
#   'me': 57,
#   'a': 19,
#   'reservations': 6,
#   'seating': 5,
#   'some': 2,
#   'nine': 1,
#   'together': 1,
#   'seats': 1,
#   '4': 1,
#   'bread': 1,
#   'chicken': 1,
#   'warmer': 6,
#   'chillier': 12,
#   'colder': 7,
#   'cold': 2,
#   'chilly': 4,
#   'close': 1,
#   'the': 65,
#   'hotter': 8,
#   'here': 1,
#   'rainy': 1,
#   'any': 1,
#   'overcast': 1,
#   'windy': 4,
#   'foggy': 1,
#   'within': 1,
#   'this': 1,
#   'cloudy': 1,
#   'lit': 1,
#   'ideas': 1,
#   'up': 1,
#   'zero': 1,
#   'deadly': 1,
#   'out': 1,
#   '2': 2,
#   '0': 2,
#   'four': 1,
#   '1': 1,
#   '6': 1,
#   'intel': 1,
#   'fight': 1,
#   'it': 2,
#   'painting': 2,
#   'album': 1,
#   'saga': 2,
#   'jump': 1,
#   'soundtrack': 1,
#   'harry': 1,
#   'photograph': 1,
#   '?': 1,
#   'lahore': 1,
#   'todays': 2,
#   'showtimes': 1,
#   'movie': 1},
#  'munia': {'the': 1},
#  'tale': {'to': 1, 'of': 8},
#  'adrenaline': {'workout': 3},
#  'molly': {'and': 1, 'mcguire': 1, 'at': 1, 'want': 1},
#  'tenbrooks': {'in': 1},
#  'french': {'n': 3,
#   'restaurant': 1,
#   'at': 1,
#   'horn': 1,
#   'food': 1,
#   'in': 1,
#   'polynesia': 6,
#   'southern': 3,
#   'laundry': 2,
#   '?': 1,
#   ',': 1,
#   'poets': 1,
#   'suicide': 1,
#   'chef': 1},
#  'n': {"'": 3, 'tity': 1, 'bone': 2, 'and': 1},
#  'twink': {'to': 1},
#  'blurred': {'crusade': 1},
#  'crusade': {'to': 1},
#  'crate': {'diggers': 3},
#  'diggers': {'anonymous': 3},
#  'robyn': {'hitchcock': 1, 'martinez': 1},
#  'hitchcock': {'to': 1, 'fl': 1},
#  'romantic': {'evening': 2, 'photograph': 1},
#  'beatles': {'tune': 1},
#  'yesterday': {'to': 1, 'the': 1},
#  'enduser': {'song': 1},
#  'grime': {'instrumentals': 4, 'shutdown': 2},
#  'koichi': {'sugiyama': 1, 'domoto': 1},
#  'sugiyama': {'to': 1},
#  'sungmin': {'into': 1},
#  'summer': {'playlist': 1,
#   'of': 4,
#   'music': 1,
#   'in': 4,
#   '?': 2,
#   'not': 1,
#   'job': 1,
#   'king': 1,
#   'with': 1,
#   'school': 1},
#  'little': {'musgrave': 1,
#   'walter': 1,
#   'children': 1,
#   'house': 1,
#   'grey': 1,
#   'pattie': 1,
#   'grill': 1,
#   'manatee': 1,
#   'silver': 1,
#   'robin': 1,
#   'book': 1,
#   'death': 2,
#   'band': 1,
#   'pigs': 1,
#   'girl': 1,
#   'toaster': 1,
#   'tree': 1,
#   'curious': 1,
#   'computer': 1,
#   'less': 1,
#   'more': 1,
#   'thing': 1,
#   'something': 1,
#   'things': 1,
#   'crook': 1,
#   'bit': 1,
#   'red': 1,
#   'irish': 1},
#  'musgrave': {'and': 1},
#  'barnard': {'to': 1},
#  'ora': {"'s": 1},
#  'riddim': {'driven': 1},
#  'driven': {'engine': 1, 'to': 1},
#  'engine': {'54': 1},
#  '54': {'&': 1},
#  'humanity': {'letha': 1},
#  'letha': {"'s": 2},
#  'kitade': {'to': 1},
#  'modern': {'psychedelia': 1,
#   'history': 1,
#   'glamour': 1,
#   'world': 1,
#   'times': 1,
#   'love': 1},
#  'psychedelia': {'playlist': 1},
#  'ares': {'in': 1},
#  'canadian': {'country': 3, 'mounted': 2},
#  'parents': {'playlist': 2, 'and': 3},
#  'hype': {'playlist': 3, 'the': 1, 'list': 1},
#  'nib': {'to': 1},
#  'fay': {"'s": 1},
#  'beat': {'playlist': 3, '?': 1, 'street': 1, 'should': 1, ',': 1, 'the': 2},
#  'patrica': {"'s": 1},
#  'insert': {'rock': 1},
#  'martine': {'mccutcheon': 1},
#  'mccutcheon': {'to': 1},
#  'original': {'columbia': 1,
#   'house': 1,
#   'spanish': 1,
#   'soup': 1,
#   'motion': 2,
#   'recordings': 1},
#  'columbia': {'jazzmasters': 1,
#   'and': 1,
#   'for': 1,
#   '.': 1,
#   '?': 2,
#   ',': 1,
#   'album': 1},
#  'jazzmasters': {'list': 1},
#  'autry': {'inman': 1},
#  'inman': {'to': 1},
#  'hanging': {'out': 3, 'on': 2, 'in': 1, 'valley': 1},
#  'towel': {'to': 1},
#  'blaise': {'to': 1},
#  'chips': {'and': 1,
#   'in': 2,
#   'on': 1,
#   'for': 1,
#   '.': 1,
#   'one': 1,
#   'showing': 1},
#  'salsa': {'playlist': 1, 'classics': 2, 'music': 1},
#  'mac': {"'n": 2, 'wiseman': 1, 'to': 1, 'and': 1, 'dre': 1},
#  "'n": {'cheese': 2, "'": 1},
#  'cheese': {'playlist': 2,
#   'course': 1,
#   'fries': 2,
#   'steak': 1,
#   'man': 1,
#   '?': 1},
#  'willie': {'nelson': 2, 'dixon': 1},
#  'style': {'to': 2, 'restaurant': 1, 'music': 2, 'three': 1},
#  'spinnin': {"'": 2},
#  'records': {'top': 2, 'and': 1},
#  'harris': {'to': 1, "'s": 2, 'false': 1},
#  ...}

# %%
predict=hmm.predict_next_word("can I")
print(predict[0])
# Out:
# {'next_word': 'want', 'prob': 0.27044025157232704}

# %%
predict1=hmm.predict_next_word_given_first_letters("add Unite and Win to my night o")
print(predict1)
# Out:
# ({'next_word': 'out', 'prob': 0.16216216216216217}, ['out', 'on'], [0.16216216216216217, 0.05405405405405406])

# %%
import matplotlib.pyplot as plt
x =predict[1]
y =predict[2]
fig, ax = plt.subplots()
ax.bar(x, y, width=0.5, edgecolor="black", linewidth=0.1)
plt.title("comparison between best word and some random words")
plt.show()

# %%
import matplotlib.pyplot as plt
x =predict1[1]
y =predict1[2]
fig, ax = plt.subplots()
ax.bar(x, y, width=0.5, edgecolor="black", linewidth=0.1)
plt.title("comparison between best word and some random words(givien first letters)")
plt.show()
